# %%
#I have 3 datasets from NYC OPENDATA that I am going to clean.

# %%
import pandas as pd
import os

# %%
# Path to data folder relative to the notebook
DATA_DIR = os.path.join("..", "data", "raw")

# %%
#Clean bus evasion dataset

# %%
bus_evasion_df = pd.read_csv(os.path.join(DATA_DIR, "MTA_Bus_Fare_Evasion__Beginning_2019_20250721.csv"))
#subway_evasion_df = pd.read_csv(os.path.join(DATA_DIR, "MTA_NYCT_Subway_Fare_Evasion__Beginning_2018_20250721.csv"))
#ridership_df = pd.read_csv(os.path.join(DATA_DIR, "MTA_Daily_Ridership_Data__2020_-_2025_20250721.csv"))

# %%
bus_evasion_df.head(10)
# Out:
#   Time Period Trip Type  Fare Evasion
# 0     2019-Q1     Local         0.250
# 1     2019-Q2     Local         0.279
# 2     2019-Q3     Local         0.210
# 3     2019-Q4     Local         0.206
# 4     2020-Q1     Local         0.211
# 5     2020-Q2     Local           NaN
# 6     2020-Q3     Local           NaN
# 7     2020-Q4     Local         0.233
# 8     2020-Q4   Express         0.047
# 9     2021-Q1     Local         0.236

# %%
bus_evasion_df.info()
bus_evasion_df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 78 entries, 0 to 77
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Time Period   78 non-null     object
#  1   Trip Type     78 non-null     object
#  2   Fare Evasion  76 non-null     float64
# dtypes: float64(1), object(2)
# memory usage: 2.0+ KB
#        Fare Evasion
# count     76.000000
# mean       0.303678
# std        0.165992
# min        0.036000
# 25%        0.209000
# 50%        0.327500
# 75%        0.441250
# max        0.576000

# %%
bus_evasion_df['Fare Evasion'] = bus_evasion_df['Fare Evasion'].interpolate(method='linear')

# %%
# First create a datetime column
bus_evasion_df['Year'] = bus_evasion_df['Time Period'].str[:4].astype(int)
bus_evasion_df['Quarter'] = bus_evasion_df['Time Period'].str[-2:]

# Map quarter to month for datetime approximation (e.g. Q1 → Feb)
quarter_month_map = {'Q1': 2, 'Q2': 5, 'Q3': 8, 'Q4': 11}
bus_evasion_df['Month'] = bus_evasion_df['Quarter'].map(quarter_month_map)

# Combine into a datetime
bus_evasion_df['Date'] = pd.to_datetime(dict(year=bus_evasion_df.Year, month=bus_evasion_df.Month, day=1))
bus_evasion_df['Mode'] = "Buses"

# %%
bus_evasion_df
# Out:
#    Time Period Trip Type  Fare Evasion  Year Quarter  Month       Date   Mode
# 0      2019-Q1     Local         0.250  2019      Q1      2 2019-02-01  Buses
# 1      2019-Q2     Local         0.279  2019      Q2      5 2019-05-01  Buses
# 2      2019-Q3     Local         0.210  2019      Q3      8 2019-08-01  Buses
# 3      2019-Q4     Local         0.206  2019      Q4     11 2019-11-01  Buses
# 4      2020-Q1     Local         0.211  2020      Q1      2 2020-02-01  Buses
# ..         ...       ...           ...   ...     ...    ...        ...    ...
# 73     2024-Q4     Total         0.449  2024      Q4     11 2024-11-01  Buses
# 74     2025-Q1   Express         0.036  2025      Q1      2 2025-02-01  Buses
# 75     2025-Q1     Local         0.430  2025      Q1      2 2025-02-01  Buses
# 76     2025-Q1       SBS         0.558  2025      Q1      2 2025-02-01  Buses
# 77     2025-Q1     Total         0.440  2025      Q1      2 2025-02-01  Buses
#
# [78 rows x 8 columns]

# %%
# Get the absolute path to the project root
project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))

# Construct the full path to the output file
output_path = os.path.join(project_root, "data", "processed", "bus_evasion_df.csv")

# Save the CSV
bus_evasion_df.to_csv(output_path, index=False)

# %%
#Clean Subway Evasion Dataset

# %%
subway_evasion_df = pd.read_csv(os.path.join(DATA_DIR, "MTA_NYCT_Subway_Fare_Evasion__Beginning_2018_20250721.csv"))

# %%
subway_evasion_df.head(20)
# Out:
#    Time Period  Fare Evasion  Margin of Error
# 0      2018-Q1         0.028              NaN
# 1      2018-Q2         0.029              NaN
# 2      2018-Q3         0.038              NaN
# 3      2018-Q4         0.034              NaN
# 4      2019-Q1         0.039              NaN
# 5      2019-Q2         0.039              NaN
# 6      2019-Q3         0.057              NaN
# 7      2019-Q4         0.049              NaN
# 8      2020-Q1         0.062            0.013
# 9      2020-Q2           NaN              NaN
# 10     2020-Q3         0.136            0.011
# 11     2020-Q4         0.117            0.008
# 12     2021-Q1         0.113            0.009
# 13     2021-Q2         0.106            0.008
# 14     2021-Q3         0.092            0.011
# 15     2021-Q4         0.098            0.016
# 16     2022-Q1         0.125            0.015
# 17     2022-Q2         0.122            0.012
# 18     2022-Q3         0.134            0.012
# 19     2022-Q4         0.135            0.016

# %%
subway_evasion_df.info()
subway_evasion_df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29 entries, 0 to 28
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Time Period      29 non-null     object
#  1   Fare Evasion     28 non-null     float64
#  2   Margin of Error  20 non-null     float64
# dtypes: float64(2), object(1)
# memory usage: 824.0+ bytes
#        Fare Evasion  Margin of Error
# count     28.000000        20.000000
# mean       0.095321         0.011050
# std        0.040236         0.002481
# min        0.028000         0.008000
# 25%        0.055000         0.009000
# 50%        0.108500         0.011000
# 75%        0.131500         0.012000
# max        0.140000         0.016000

# %%
# Option 1: leave as is
# Option 2: subway_evasion_df.drop(columns="Margin of Error", inplace=True)
# Option 3: Estimate using post-2020 values
post_2020 = subway_evasion_df[subway_evasion_df["Margin of Error"].notna()]
avg_ratio = (post_2020["Margin of Error"] / post_2020["Fare Evasion"]).mean()
subway_evasion_df["Margin of Error"] = subway_evasion_df["Margin of Error"].fillna(
    subway_evasion_df["Fare Evasion"] * avg_ratio
)

# %%
# Option A: Convert to datetime by using the first month of the quarter
#subway_evasion_df["Date"] = pd.to_datetime(subway_evasion_df["Time Period"].str.replace("Q", "-") + "-01")
# Option B: Use pandas Period for quarterly frequency
#subway_evasion_df["Quarter"] = pd.PeriodIndex(subway_evasion_df["Time Period"], freq='Q')

# First create a datetime column
subway_evasion_df['Year'] = subway_evasion_df['Time Period'].str[:4].astype(int)
subway_evasion_df['Quarter'] = subway_evasion_df['Time Period'].str[-2:]

# Map quarter to month for datetime approximation (e.g. Q1 → Feb)
quarter_month_map = {'Q1': 2, 'Q2': 5, 'Q3': 8, 'Q4': 11}
subway_evasion_df['Month'] = subway_evasion_df['Quarter'].map(quarter_month_map)

# Combine into a datetime
bus_evasion_df['Date'] = pd.to_datetime(dict(year=bus_evasion_df.Year, month=bus_evasion_df.Month, day=1))

# %%
subway_evasion_df.info()
subway_evasion_df.describe()
subway_evasion_df.plot(y="Fare Evasion", use_index=True, marker='o')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29 entries, 0 to 28
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Time Period      29 non-null     object
#  1   Fare Evasion     28 non-null     float64
#  2   Margin of Error  28 non-null     float64
#  3   Year             29 non-null     int64
#  4   Quarter          29 non-null     object
#  5   Month            29 non-null     int64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 1.5+ KB
# <Axes: >

# %%
subway_evasion_df.head(20)
# Out:
#    Time Period  Fare Evasion  Margin of Error  Year Quarter  Month
# 0      2018-Q1         0.028         0.002733  2018      Q1      2
# 1      2018-Q2         0.029         0.002831  2018      Q2      5
# 2      2018-Q3         0.038         0.003709  2018      Q3      8
# 3      2018-Q4         0.034         0.003319  2018      Q4     11
# 4      2019-Q1         0.039         0.003807  2019      Q1      2
# 5      2019-Q2         0.039         0.003807  2019      Q2      5
# 6      2019-Q3         0.057         0.005564  2019      Q3      8
# 7      2019-Q4         0.049         0.004783  2019      Q4     11
# 8      2020-Q1         0.062         0.013000  2020      Q1      2
# 9      2020-Q2           NaN              NaN  2020      Q2      5
# 10     2020-Q3         0.136         0.011000  2020      Q3      8
# 11     2020-Q4         0.117         0.008000  2020      Q4     11
# 12     2021-Q1         0.113         0.009000  2021      Q1      2
# 13     2021-Q2         0.106         0.008000  2021      Q2      5
# 14     2021-Q3         0.092         0.011000  2021      Q3      8
# 15     2021-Q4         0.098         0.016000  2021      Q4     11
# 16     2022-Q1         0.125         0.015000  2022      Q1      2
# 17     2022-Q2         0.122         0.012000  2022      Q2      5
# 18     2022-Q3         0.134         0.012000  2022      Q3      8
# 19     2022-Q4         0.135         0.016000  2022      Q4     11

# %%
# Ensure the Fare Evasion and Margin of Error columns are numeric
subway_evasion_df['Fare Evasion'] = pd.to_numeric(subway_evasion_df['Fare Evasion'], errors='coerce')
subway_evasion_df['Margin of Error'] = pd.to_numeric(subway_evasion_df['Margin of Error'], errors='coerce')

# Interpolate the NaNs
subway_evasion_df[['Fare Evasion', 'Margin of Error']] = subway_evasion_df[['Fare Evasion', 'Margin of Error']].interpolate(method='linear')
subway_evasion_df["Mode"] = "Subways"

# %%
subway_evasion_df
# Out:
#    Time Period  Fare Evasion  Margin of Error  Year Quarter  Month     Mode
# 0      2018-Q1         0.028         0.002733  2018      Q1      2  Subways
# 1      2018-Q2         0.029         0.002831  2018      Q2      5  Subways
# 2      2018-Q3         0.038         0.003709  2018      Q3      8  Subways
# 3      2018-Q4         0.034         0.003319  2018      Q4     11  Subways
# 4      2019-Q1         0.039         0.003807  2019      Q1      2  Subways
# 5      2019-Q2         0.039         0.003807  2019      Q2      5  Subways
# 6      2019-Q3         0.057         0.005564  2019      Q3      8  Subways
# 7      2019-Q4         0.049         0.004783  2019      Q4     11  Subways
# 8      2020-Q1         0.062         0.013000  2020      Q1      2  Subways
# 9      2020-Q2         0.099         0.012000  2020      Q2      5  Subways
# 10     2020-Q3         0.136         0.011000  2020      Q3      8  Subways
# 11     2020-Q4         0.117         0.008000  2020      Q4     11  Subways
# 12     2021-Q1         0.113         0.009000  2021      Q1      2  Subways
# 13     2021-Q2         0.106         0.008000  2021      Q2      5  Subways
# 14     2021-Q3         0.092         0.011000  2021      Q3      8  Subways
# 15     2021-Q4         0.098         0.016000  2021      Q4     11  Subways
# 16     2022-Q1         0.125         0.015000  2022      Q1      2  Subways
# 17     2022-Q2         0.122         0.012000  2022      Q2      5  Subways
# 18     2022-Q3         0.134         0.012000  2022      Q3      8  Subways
# 19     2022-Q4         0.135         0.016000  2022      Q4     11  Subways
# 20     2023-Q1         0.111         0.009000  2023      Q1      2  Subways
# 21     2023-Q2         0.123         0.011000  2023      Q2      5  Subways
# 22     2023-Q3         0.140         0.012000  2023      Q3      8  Subways
# 23     2023-Q4         0.133         0.010000  2023      Q4     11  Subways
# 24     2024-Q1         0.136         0.009000  2024      Q1      2  Subways
# 25     2024-Q2         0.140         0.011000  2024      Q2      5  Subways
# 26     2024-Q3         0.131         0.011000  2024      Q3      8  Subways
# 27     2024-Q4         0.104         0.008000  2024      Q4     11  Subways
# 28     2025-Q1         0.098         0.009000  2025      Q1      2  Subways

# %%
# Get the absolute path to the project root
project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))

# Construct the full path to the output file
output_path = os.path.join(project_root, "data", "processed", "subway_evasion_df.csv")

# Save the CSV
subway_evasion_df.to_csv(output_path, index=False)

# %%
#MTA Daily ridership data

# %%
ridership_df = pd.read_csv(os.path.join(DATA_DIR, "MTA_Daily_Ridership_Data__2020_-_2025_20250721.csv"))

# %%
ridership_df.head(10)
# Out:
#          Date  Subways: Total Estimated Ridership  \
# 0  03/01/2020                             2212965
# 1  03/02/2020                             5329915
# 2  03/03/2020                             5481103
# 3  03/04/2020                             5498809
# 4  03/05/2020                             5496453
# 5  03/06/2020                             5189447
# 6  03/07/2020                             2814637
# 7  03/08/2020                             2120656
# 8  03/09/2020                             4973513
# 9  03/10/2020                             4867818
#
#    Subways: % of Comparable Pre-Pandemic Day  \
# 0                                       0.97
# 1                                       0.96
# 2                                       0.98
# 3                                       0.99
# 4                                       0.99
# 5                                       0.93
# 6                                       0.92
# 7                                       0.93
# 8                                       0.89
# 9                                       0.87
#
#    Buses: Total Estimated Ridership  Buses: % of Comparable Pre-Pandemic Day  \
# 0                            984908                                     0.99
# 1                           2209066                                     0.99
# 2                           2228608                                     0.99
# 3                           2177165                                     0.97
# 4                           2244515                                     1.00
# 5                           2066743                                     0.92
# 6                           1249085                                     0.94
# 7                            957163                                     0.96
# 8                           2124770                                     0.95
# 9                           2111989                                     0.94
#
#    LIRR: Total Estimated Ridership  LIRR: % of Comparable Pre-Pandemic Day  \
# 0                            86790                                    1.00
# 1                           321569                                    1.03
# 2                           319727                                    1.02
# 3                           311662                                    0.99
# 4                           307597                                    0.98
# 5                           289171                                    0.92
# 6                           106058                                    0.98
# 7                            81565                                    0.94
# 8                           277001                                    0.88
# 9                           259324                                    0.83
#
#    Metro-North: Total Estimated Ridership  \
# 0                                   55825
# 1                                  180701
# 2                                  190648
# 3                                  192689
# 4                                  194386
# 5                                  205056
# 6                                   75838
# 7                                   60800
# 8                                  183953
# 9                                  179050
#
#    Metro-North: % of Comparable Pre-Pandemic Day  \
# 0                                           0.59
# 1                                           0.66
# 2                                           0.69
# 3                                           0.70
# 4                                           0.70
# 5                                           0.74
# 6                                           0.56
# 7                                           0.64
# 8                                           0.67
# 9                                           0.65
#
#    Access-A-Ride: Total Scheduled Trips  \
# 0                                 19922
# 1                                 30338
# 2                                 32767
# 3                                 34297
# 4                                 33209
# 5                                 30970
# 6                                 18117
# 7                                 19477
# 8                                 29609
# 9                                 31315
#
#    Access-A-Ride: % of Comparable Pre-Pandemic Day  \
# 0                                             1.13
# 1                                             1.02
# 2                                             1.10
# 3                                             1.15
# 4                                             1.12
# 5                                             1.04
# 6                                             1.07
# 7                                             1.11
# 8                                             1.00
# 9                                             1.05
#
#    Bridges and Tunnels: Total Traffic  \
# 0                              786960
# 1                              874619
# 2                              882175
# 3                              905558
# 4                              929298
# 5                              945408
# 6                              827907
# 7                              765083
# 8                              860073
# 9                              855585
#
#    Bridges and Tunnels: % of Comparable Pre-Pandemic Day  \
# 0                                               0.98
# 1                                               0.95
# 2                                               0.96
# 3                                               0.98
# 4                                               1.01
# 5                                               1.03
# 6                                               0.95
# 7                                               0.95
# 8                                               0.93
# 9                                               0.93
#
#    Staten Island Railway: Total Estimated Ridership  \
# 0                                              1636
# 1                                             17140
# 2                                             17453
# 3                                             17136
# 4                                             17203
# 5                                             15285
# 6                                              2445
# 7                                              1672
# 8                                             16122
# 9                                             15805
#
#    Staten Island Railway: % of Comparable Pre-Pandemic Day
# 0                                               0.52
# 1                                               1.07
# 2                                               1.09
# 3                                               1.07
# 4                                               1.08
# 5                                               0.96
# 6                                               0.48
# 7                                               0.53
# 8                                               1.01
# 9                                               0.99

# %%
ridership_df.info()
ridership_df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1776 entries, 0 to 1775
# Data columns (total 15 columns):
#  #   Column                                                   Non-Null Count  Dtype
# ---  ------                                                   --------------  -----
#  0   Date                                                     1776 non-null   object
#  1   Subways: Total Estimated Ridership                       1776 non-null   int64
#  2   Subways: % of Comparable Pre-Pandemic Day                1776 non-null   float64
#  3   Buses: Total Estimated Ridership                         1776 non-null   int64
#  4   Buses: % of Comparable Pre-Pandemic Day                  1776 non-null   float64
#  5   LIRR: Total Estimated Ridership                          1776 non-null   int64
#  6   LIRR: % of Comparable Pre-Pandemic Day                   1776 non-null   float64
#  7   Metro-North: Total Estimated Ridership                   1776 non-null   int64
#  8   Metro-North: % of Comparable Pre-Pandemic Day            1776 non-null   float64
#  9   Access-A-Ride: Total Scheduled Trips                     1776 non-null   int64
#  10  Access-A-Ride: % of Comparable Pre-Pandemic Day          1776 non-null   float64
#  11  Bridges and Tunnels: Total Traffic                       1776 non-null   int64
#  12  Bridges and Tunnels: % of Comparable Pre-Pandemic Day    1776 non-null   float64
#  13  Staten Island Railway: Total Estimated Ridership         1776 non-null   int64
#  14  Staten Island Railway: % of Comparable Pre-Pandemic Day  1776 non-null   float64
# dtypes: float64(7), int64(7), object(1)
# memory usage: 208.2+ KB
#        Subways: Total Estimated Ridership  \
# count                        1.776000e+03
# mean                         2.541830e+06
# std                          1.067641e+06
# min                          1.983990e+05
# 25%                          1.735692e+06
# 50%                          2.505354e+06
# 75%                          3.476191e+06
# max                          5.498809e+06
#
#        Subways: % of Comparable Pre-Pandemic Day  \
# count                                1776.000000
# mean                                    0.563615
# std                                     0.201075
# min                                     0.070000
# 25%                                     0.420000
# 50%                                     0.610000
# 75%                                     0.700000
# max                                     1.430000
#
#        Buses: Total Estimated Ridership  \
# count                      1.776000e+03
# mean                       1.011409e+06
# std                        4.369798e+05
# min                        5.498000e+03
# 25%                        7.186188e+05
# 50%                        1.143659e+06
# 75%                        1.350378e+06
# max                        2.244515e+06
#
#        Buses: % of Comparable Pre-Pandemic Day  \
# count                              1776.000000
# mean                                  0.551644
# std                                   0.191883
# min                                   0.010000
# 25%                                   0.530000
# 50%                                   0.600000
# 75%                                   0.650000
# max                                   1.260000
#
#        LIRR: Total Estimated Ridership  \
# count                      1776.000000
# mean                     138783.668919
# std                       72243.727072
# min                        1903.000000
# 25%                       80255.750000
# 50%                      127684.500000
# 75%                      201384.750000
# max                      321569.000000
#
#        LIRR: % of Comparable Pre-Pandemic Day  \
# count                             1776.000000
# mean                                 0.607432
# std                                  0.308112
# min                                  0.020000
# 25%                                  0.377500
# 50%                                  0.620000
# 75%                                  0.770000
# max                                  2.570000
#
#        Metro-North: Total Estimated Ridership  \
# count                             1776.000000
# mean                            117522.400338
# std                              67232.358363
# min                               3281.000000
# 25%                              53755.000000
# 50%                             111431.000000
# 75%                             180373.250000
# max                             249585.000000
#
#        Metro-North: % of Comparable Pre-Pandemic Day  \
# count                                    1776.000000
# mean                                        0.525631
# std                                         0.272096
# min                                         0.030000
# 25%                                         0.310000
# 50%                                         0.575000
# 75%                                         0.720000
# max                                         2.110000
#
#        Access-A-Ride: Total Scheduled Trips  \
# count                           1776.000000
# mean                           22349.481982
# std                             8232.384206
# min                             2506.000000
# 25%                            16250.000000
# 50%                            22462.000000
# 75%                            28125.000000
# max                            41858.000000
#
#        Access-A-Ride: % of Comparable Pre-Pandemic Day  \
# count                                      1776.000000
# mean                                          0.878846
# std                                           0.257712
# min                                           0.130000
# 25%                                           0.720000
# 50%                                           0.850000
# 75%                                           1.060000
# max                                           1.770000
#
#        Bridges and Tunnels: Total Traffic  \
# count                        1.776000e+03
# mean                         8.572596e+05
# std                          1.412100e+05
# min                          1.567590e+05
# 25%                          8.139142e+05
# 50%                          8.972120e+05
# 75%                          9.472925e+05
# max                          1.043802e+06
#
#        Bridges and Tunnels: % of Comparable Pre-Pandemic Day  \
# count                                        1776.000000
# mean                                            0.937297
# std                                             0.144921
# min                                             0.180000
# 25%                                             0.910000
# 50%                                             0.980000
# 75%                                             1.020000
# max                                             1.200000
#
#        Staten Island Railway: Total Estimated Ridership  \
# count                                       1776.000000
# mean                                        4491.962838
# std                                         2700.110378
# min                                            0.000000
# 25%                                         2121.500000
# 50%                                         4568.500000
# 75%                                         6845.500000
# max                                        17453.000000
#
#        Staten Island Railway: % of Comparable Pre-Pandemic Day
# count                                        1776.000000
# mean                                            0.387934
# std                                             0.202076
# min                                             0.000000
# 25%                                             0.260000
# 50%                                             0.400000
# 75%                                             0.470000
# max                                             1.820000

# %%
# Remove extra spaces and standardize names
ridership_df.columns = ridership_df.columns.str.strip()

# %%
ridership_long = pd.melt(
    ridership_df,
    id_vars=["Date"],
    var_name="Mode_Metric",
    value_name="Value"
)

# %%
# Split on ": " to get Mode and Metric
ridership_long[['Mode', 'Metric']] = ridership_long['Mode_Metric'].str.split(': ', expand=True)

# Drop the combined column
ridership_long = ridership_long.drop(columns='Mode_Metric')

# %%
ridership_long
# Out:
#              Date       Value                   Mode  \
# 0      03/01/2020  2212965.00                Subways
# 1      03/02/2020  5329915.00                Subways
# 2      03/03/2020  5481103.00                Subways
# 3      03/04/2020  5498809.00                Subways
# 4      03/05/2020  5496453.00                Subways
# ...           ...         ...                    ...
# 24859  01/05/2025        0.74  Staten Island Railway
# 24860  01/06/2025        0.42  Staten Island Railway
# 24861  01/07/2025        0.45  Staten Island Railway
# 24862  01/08/2025        0.48  Staten Island Railway
# 24863  01/09/2025        0.42  Staten Island Railway
#
#                                  Metric
# 0             Total Estimated Ridership
# 1             Total Estimated Ridership
# 2             Total Estimated Ridership
# 3             Total Estimated Ridership
# 4             Total Estimated Ridership
# ...                                 ...
# 24859  % of Comparable Pre-Pandemic Day
# 24860  % of Comparable Pre-Pandemic Day
# 24861  % of Comparable Pre-Pandemic Day
# 24862  % of Comparable Pre-Pandemic Day
# 24863  % of Comparable Pre-Pandemic Day
#
# [24864 rows x 4 columns]

# %%
ridership_long.columns
# Out:
# Index(['Date', 'Value', 'Mode', 'Metric'], dtype='object')

# %%
# Ensure 'Date' column is in datetime format
ridership_long['Date'] = pd.to_datetime(ridership_long['Date'])

# Add Year, Month, Quarter columns
ridership_long['Year'] = ridership_long['Date'].dt.year
ridership_long['Month'] = ridership_long['Date'].dt.month
ridership_long['Quarter'] = ridership_long['Date'].dt.to_period('Q').astype(str)

# Optional: Add month name if desired
ridership_long['Month_Name'] = ridership_long['Date'].dt.month_name()
# Strip the year from the 'Quarter' column, leaving just 'Q1', 'Q2', etc.
ridership_long['Quarter'] = ridership_long['Quarter'].str.extract(r'(Q[1-4])')

# %%
# Get the absolute path to the project root
project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))

# Construct the full path to the output file
output_path = os.path.join(project_root, "data", "processed", "ridership_long.csv")

# Save the CSV
ridership_long.to_csv(output_path, index=False)

# %%
ridership_long
# Out:
#             Date       Value                   Mode  \
# 0     2020-03-01  2212965.00                Subways
# 1     2020-03-02  5329915.00                Subways
# 2     2020-03-03  5481103.00                Subways
# 3     2020-03-04  5498809.00                Subways
# 4     2020-03-05  5496453.00                Subways
# ...          ...         ...                    ...
# 24859 2025-01-05        0.74  Staten Island Railway
# 24860 2025-01-06        0.42  Staten Island Railway
# 24861 2025-01-07        0.45  Staten Island Railway
# 24862 2025-01-08        0.48  Staten Island Railway
# 24863 2025-01-09        0.42  Staten Island Railway
#
#                                  Metric  Year  Month Quarter Month_Name
# 0             Total Estimated Ridership  2020      3      Q1      March
# 1             Total Estimated Ridership  2020      3      Q1      March
# 2             Total Estimated Ridership  2020      3      Q1      March
# 3             Total Estimated Ridership  2020      3      Q1      March
# 4             Total Estimated Ridership  2020      3      Q1      March
# ...                                 ...   ...    ...     ...        ...
# 24859  % of Comparable Pre-Pandemic Day  2025      1      Q1    January
# 24860  % of Comparable Pre-Pandemic Day  2025      1      Q1    January
# 24861  % of Comparable Pre-Pandemic Day  2025      1      Q1    January
# 24862  % of Comparable Pre-Pandemic Day  2025      1      Q1    January
# 24863  % of Comparable Pre-Pandemic Day  2025      1      Q1    January
#
# [24864 rows x 8 columns]

# %%
import calendar

bus_monthly_stats = ridership_long[(ridership_long['Mode']=='Buses') & (ridership_long['Metric']=='% of Comparable Pre-Pandemic Day')]
#df_filtered = df_joined_bus_final[(df_joined_bus_final['Year'] >= 2021) & (df_joined_bus_final['Year'] <= 2024)]

bus_monthly_stats = bus_monthly_stats.groupby(['Year', 'Month', 'Metric', 'Quarter'])['Value'].mean().reset_index()

# Convert numeric Month to full month name
bus_monthly_stats['Month'] = bus_monthly_stats['Month'].apply(lambda x: calendar.month_name[x])


# Get the absolute path to the project root
project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))

# Construct the full path to the output file
output_path = os.path.join(project_root, "data", "processed", "bus_monthly_stats.csv")

# Save the CSV
bus_monthly_stats.to_csv(output_path, index=False)
bus_monthly_stats
# Out:
#     Year      Month                            Metric Quarter     Value
# 0   2020      March  % of Comparable Pre-Pandemic Day      Q1  0.534194
# 1   2020      April  % of Comparable Pre-Pandemic Day      Q2  0.010000
# 2   2020        May  % of Comparable Pre-Pandemic Day      Q2  0.010000
# 3   2020       June  % of Comparable Pre-Pandemic Day      Q2  0.012000
# 4   2020       July  % of Comparable Pre-Pandemic Day      Q3  0.015806
# 5   2020     August  % of Comparable Pre-Pandemic Day      Q3  0.028387
# 6   2020  September  % of Comparable Pre-Pandemic Day      Q3  0.477000
# 7   2020    October  % of Comparable Pre-Pandemic Day      Q4  0.506452
# 8   2020   November  % of Comparable Pre-Pandemic Day      Q4  0.531333
# 9   2020   December  % of Comparable Pre-Pandemic Day      Q4  0.488065
# 10  2021    January  % of Comparable Pre-Pandemic Day      Q1  0.496774
# 11  2021   February  % of Comparable Pre-Pandemic Day      Q1  0.463214
# 12  2021      March  % of Comparable Pre-Pandemic Day      Q1  0.493871
# 13  2021      April  % of Comparable Pre-Pandemic Day      Q2  0.537000
# 14  2021        May  % of Comparable Pre-Pandemic Day      Q2  0.556452
# 15  2021       June  % of Comparable Pre-Pandemic Day      Q2  0.594000
# 16  2021       July  % of Comparable Pre-Pandemic Day      Q3  0.590968
# 17  2021     August  % of Comparable Pre-Pandemic Day      Q3  0.585806
# 18  2021  September  % of Comparable Pre-Pandemic Day      Q3  0.599000
# 19  2021    October  % of Comparable Pre-Pandemic Day      Q4  0.641935
# 20  2021   November  % of Comparable Pre-Pandemic Day      Q4  0.670333
# 21  2021   December  % of Comparable Pre-Pandemic Day      Q4  0.635484
# 22  2022    January  % of Comparable Pre-Pandemic Day      Q1  0.543226
# 23  2022   February  % of Comparable Pre-Pandemic Day      Q1  0.605714
# 24  2022      March  % of Comparable Pre-Pandemic Day      Q1  0.623226
# 25  2022      April  % of Comparable Pre-Pandemic Day      Q2  0.631667
# 26  2022        May  % of Comparable Pre-Pandemic Day      Q2  0.642258
# 27  2022       June  % of Comparable Pre-Pandemic Day      Q2  0.656667
# 28  2022       July  % of Comparable Pre-Pandemic Day      Q3  0.631935
# 29  2022     August  % of Comparable Pre-Pandemic Day      Q3  0.635484
# 30  2022  September  % of Comparable Pre-Pandemic Day      Q3  0.625000
# 31  2022    October  % of Comparable Pre-Pandemic Day      Q4  0.646129
# 32  2022   November  % of Comparable Pre-Pandemic Day      Q4  0.674667
# 33  2022   December  % of Comparable Pre-Pandemic Day      Q4  0.635161
# 34  2023    January  % of Comparable Pre-Pandemic Day      Q1  0.681935
# 35  2023   February  % of Comparable Pre-Pandemic Day      Q1  0.658571
# 36  2023      March  % of Comparable Pre-Pandemic Day      Q1  0.657419
# 37  2023      April  % of Comparable Pre-Pandemic Day      Q2  0.647000
# 38  2023        May  % of Comparable Pre-Pandemic Day      Q2  0.661613
# 39  2023       June  % of Comparable Pre-Pandemic Day      Q2  0.650667
# 40  2023       July  % of Comparable Pre-Pandemic Day      Q3  0.625484
# 41  2023     August  % of Comparable Pre-Pandemic Day      Q3  0.629032
# 42  2023  September  % of Comparable Pre-Pandemic Day      Q3  0.590000
# 43  2023    October  % of Comparable Pre-Pandemic Day      Q4  0.612581
# 44  2023   November  % of Comparable Pre-Pandemic Day      Q4  0.630000
# 45  2023   December  % of Comparable Pre-Pandemic Day      Q4  0.588065
# 46  2024    January  % of Comparable Pre-Pandemic Day      Q1  0.599677
# 47  2024   February  % of Comparable Pre-Pandemic Day      Q1  0.600690
# 48  2024      March  % of Comparable Pre-Pandemic Day      Q1  0.585484
# 49  2024      April  % of Comparable Pre-Pandemic Day      Q2  0.588333
# 50  2024        May  % of Comparable Pre-Pandemic Day      Q2  0.585484
# 51  2024       June  % of Comparable Pre-Pandemic Day      Q2  0.603333
# 52  2024       July  % of Comparable Pre-Pandemic Day      Q3  0.576774
# 53  2024     August  % of Comparable Pre-Pandemic Day      Q3  0.561613
# 54  2024  September  % of Comparable Pre-Pandemic Day      Q3  0.630667
# 55  2024    October  % of Comparable Pre-Pandemic Day      Q4  0.663548
# 56  2024   November  % of Comparable Pre-Pandemic Day      Q4  0.682000
# 57  2024   December  % of Comparable Pre-Pandemic Day      Q4  0.656774
# 58  2025    January  % of Comparable Pre-Pandemic Day      Q1  0.585556

# %%
# Group by Year, Quarter, Metric, and Mode to get mean and variance
quarterly_stats = (
    ridership_long
    .groupby(['Year', 'Quarter', 'Metric', 'Mode'], as_index=False)
    .agg(
        Avg_Value=('Value', 'mean'),
        Var_Value=('Value', 'var'),
        Sum_Value=('Value', 'sum')
    )
)

# Optional: round results
quarterly_stats['Avg_Value'] = quarterly_stats['Avg_Value'].round(2)
quarterly_stats['Var_Value'] = quarterly_stats['Var_Value'].round(2)

# %%
# Get the absolute path to the project root
project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))

# Construct the full path to the output file
output_path = os.path.join(project_root, "data", "processed", "quarterly_stats.csv")

# Save the CSV
quarterly_stats.to_csv(output_path, index=False)

# %%
quarterly_stats
# Out:
#      Year Quarter                            Metric                   Mode  \
# 0    2020      Q1  % of Comparable Pre-Pandemic Day          Access-A-Ride
# 1    2020      Q1  % of Comparable Pre-Pandemic Day    Bridges and Tunnels
# 2    2020      Q1  % of Comparable Pre-Pandemic Day                  Buses
# 3    2020      Q1  % of Comparable Pre-Pandemic Day                   LIRR
# 4    2020      Q1  % of Comparable Pre-Pandemic Day            Metro-North
# ..    ...     ...                               ...                    ...
# 289  2025      Q1         Total Estimated Ridership            Metro-North
# 290  2025      Q1         Total Estimated Ridership  Staten Island Railway
# 291  2025      Q1         Total Estimated Ridership                Subways
# 292  2025      Q1             Total Scheduled Trips          Access-A-Ride
# 293  2025      Q1                     Total Traffic    Bridges and Tunnels
#
#       Avg_Value     Var_Value    Sum_Value
# 0          0.69  1.300000e-01        21.25
# 1          0.69  7.000000e-02        21.40
# 2          0.53  1.700000e-01        16.56
# 3          0.46  1.500000e-01        14.38
# 4          0.52  3.000000e-02        15.99
# ..          ...           ...          ...
# 289   157338.44  3.340104e+09   1416046.00
# 290     5386.33  5.766114e+06     48477.00
# 291  3050981.78  7.174993e+11  27458836.00
# 292    30774.56  8.784393e+07    276971.00
# 293   803272.78  4.115071e+09   7229455.00
#
# [294 rows x 7 columns]

# %%
#Taking a look at the Mckinsey Projection Dataset

# %%
mckinsey_df = pd.read_csv(os.path.join(DATA_DIR, "MTA_McKinsey_Ridership_Projections__October_2020_-_December_2026.csv"))
# Step 1: Convert Month column to datetime
mckinsey_df['Month'] = pd.to_datetime(mckinsey_df['Month'])

# Step 2: Rename Month column to Date
mckinsey_df.rename(columns={'Month': 'Date'}, inplace=True)

# Step 3: Create Month and Year columns
mckinsey_df['Month'] = mckinsey_df['Date'].dt.strftime('%B')  # Full month name (e.g., October)
mckinsey_df['Year'] = mckinsey_df['Date'].dt.year
mckinsey_df
# Out:
#            Date            Agency             Projection  Recovery     Month  \
# 0    2020-10-01            Subway   Best Case (Dec 2020)    0.3300   October
# 1    2020-10-01            Subway    Midpoint (Dec 2020)    0.3300   October
# 2    2020-10-01            Subway  Worst Case (Dec 2020)    0.3300   October
# 3    2020-10-01               Bus   Best Case (Dec 2020)    0.4500   October
# 4    2020-10-01               Bus    Midpoint (Dec 2020)    0.4500   October
# ...         ...               ...                    ...       ...       ...
# 2704 2026-12-01               SIR    Midpoint (Apr 2022)    0.7271  December
# 2705 2026-12-01               SIR  Worst Case (Apr 2022)    0.7270  December
# 2706 2026-12-01  MTA Consolidated   Best Case (Apr 2022)    0.8810  December
# 2707 2026-12-01  MTA Consolidated    Midpoint (Apr 2022)    0.8040  December
# 2708 2026-12-01  MTA Consolidated  Worst Case (Apr 2022)    0.7280  December
#
#       Year
# 0     2020
# 1     2020
# 2     2020
# 3     2020
# 4     2020
# ...    ...
# 2704  2026
# 2705  2026
# 2706  2026
# 2707  2026
# 2708  2026
#
# [2709 rows x 6 columns]

# %%
# Ensure the 'Month' column is datetime
#mckinsey_df['Month'] = pd.to_datetime(mckinsey_df['Month'])

# Extract the scenario name from 'Projection' (e.g., "Best Case", "Midpoint", etc.)
mckinsey_df['Scenario'] = mckinsey_df['Projection'].str.extract(r'^(.*?)\s*\(')

# Format the month-year part as "AbbreviatedMonth FullYear" (e.g., "Dec 2026")
mckinsey_df['Correct_MonthYear'] = mckinsey_df['Date'].dt.strftime('%b %Y')

# Reconstruct the corrected 'Projection' column
mckinsey_df['Projection'] = mckinsey_df['Scenario'] + ' (' + mckinsey_df['Correct_MonthYear'] + ')'

# Drop the helper columns
mckinsey_df.drop(columns=['Scenario', 'Correct_MonthYear'], inplace=True)

# %%
mckinsey_df
# Out:
#            Date            Agency             Projection  Recovery     Month  \
# 0    2020-10-01            Subway   Best Case (Oct 2020)    0.3300   October
# 1    2020-10-01            Subway    Midpoint (Oct 2020)    0.3300   October
# 2    2020-10-01            Subway  Worst Case (Oct 2020)    0.3300   October
# 3    2020-10-01               Bus   Best Case (Oct 2020)    0.4500   October
# 4    2020-10-01               Bus    Midpoint (Oct 2020)    0.4500   October
# ...         ...               ...                    ...       ...       ...
# 2704 2026-12-01               SIR    Midpoint (Dec 2026)    0.7271  December
# 2705 2026-12-01               SIR  Worst Case (Dec 2026)    0.7270  December
# 2706 2026-12-01  MTA Consolidated   Best Case (Dec 2026)    0.8810  December
# 2707 2026-12-01  MTA Consolidated    Midpoint (Dec 2026)    0.8040  December
# 2708 2026-12-01  MTA Consolidated  Worst Case (Dec 2026)    0.7280  December
#
#       Year
# 0     2020
# 1     2020
# 2     2020
# 3     2020
# 4     2020
# ...    ...
# 2704  2026
# 2705  2026
# 2706  2026
# 2707  2026
# 2708  2026
#
# [2709 rows x 6 columns]

# %%
mckinsey_df = mckinsey_df[mckinsey_df['Agency'] == 'Bus']
#mckinsey_df.to_csv('/Users/danielbrown/Desktop/mckinsey_df.csv', index=False)

mckinsey_df = mckinsey_df.drop_duplicates(subset=['Month', 'Agency', 'Projection'], keep='first')
#mckinsey_df.to_csv('/Users/danielbrown/Desktop/mckinsey_df_1.csv', index=False)

# Remove the month-year part from the Projection column
mckinsey_df["Projection"] = mckinsey_df["Projection"].str.replace(r"\s+\([^)]+\)", "", regex=True)

# Optional: Check the result
print(mckinsey_df["Projection"].unique())

# Get the absolute path to the project root
project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))

# Construct the full path to the output file
output_path = os.path.join(project_root, "data", "processed", "mckinsey_df.csv")

# Save the CSV
mckinsey_df.to_csv(output_path, index=False)

mckinsey_df
# Out:
# ['Best Case' 'Midpoint' 'Worst Case']
#            Date Agency  Projection  Recovery     Month  Year
# 3    2020-10-01    Bus   Best Case    0.4500   October  2020
# 4    2020-10-01    Bus    Midpoint    0.4500   October  2020
# 5    2020-10-01    Bus  Worst Case    0.4500   October  2020
# 36   2020-11-01    Bus   Best Case    0.4500  November  2020
# 37   2020-11-01    Bus    Midpoint    0.4500  November  2020
# ...         ...    ...         ...       ...       ...   ...
# 2677 2026-11-01    Bus    Midpoint    0.8345  November  2026
# 2678 2026-11-01    Bus  Worst Case    0.7540  November  2026
# 2694 2026-12-01    Bus   Best Case    0.9160  December  2026
# 2695 2026-12-01    Bus    Midpoint    0.8355  December  2026
# 2696 2026-12-01    Bus  Worst Case    0.7550  December  2026
#
# [225 rows x 6 columns]

# %%
import matplotlib.pyplot as plt

# Filter just the Bus rows
bus_df = mckinsey_df[mckinsey_df['Agency'] == 'Bus'].sort_values('Date')

# Filter each scenario explicitly
best = bus_df[bus_df['Projection'].str.startswith('Best Case')]
mid = bus_df[bus_df['Projection'].str.startswith('Midpoint')]
worst = bus_df[bus_df['Projection'].str.startswith('Worst Case')]

# Plot
plt.figure(figsize=(12, 6))
plt.plot(best['Date'], best['Recovery'], label='Best Case', color='green')
plt.plot(mid['Date'], mid['Recovery'], label='Midpoint', color='orange')
plt.plot(worst['Date'], worst['Recovery'], label='Worst Case', color='red')

# Formatting
plt.title('Bus Ridership Recovery Projections Over Time')
plt.xlabel('Date')
plt.ylabel('Recovery Ratio')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
#Exploring the dataset that has No. Entrances each station hourly and how many are transfer
#Goal: To find the % of transfers. I want to do this to get an idea of how many people that pay fares
#are just going to transfer anyway, or have transfered. This might be another reason to make buses free
#because these people are just going to transfer anyway
#Assuming all transfers are coming from a bus

# %%
transfer_df = pd.read_csv(os.path.join(DATA_DIR, "mta_random_days_10.csv"))
transfer_df = transfer_df[['borough','ridership','transfers','transit_mode']]
transfer_df
# Out:
#           borough  ridership  transfers transit_mode
# 0          Queens        1.0        0.0       subway
# 1        Brooklyn        2.0        0.0       subway
# 2        Brooklyn        9.0        0.0       subway
# 3       Manhattan       43.0        1.0       subway
# 4       Manhattan        8.0        0.0       subway
# ...           ...        ...        ...          ...
# 691756  Manhattan        2.0        0.0       subway
# 691757  Manhattan       61.0        1.0       subway
# 691758   Brooklyn        2.0        0.0       subway
# 691759   Brooklyn        1.0        0.0       subway
# 691760      Bronx        1.0        0.0       subway
#
# [691761 rows x 4 columns]

# %%
total_ridership = transfer_df["ridership"].sum()
print(f"Total ridership: {total_ridership:.0f}")
# Out:
# Total ridership: 28835025

# %%
double_transfers = 2 * transfer_df["transfers"].sum()
print(f"Double the number of transfers: {double_transfers:.0f}")
# Out:
# Double the number of transfers: 2326946

# %%
transfer_ratio = transfer_df["transfers"].sum() / transfer_df["ridership"].sum()
print(f"Transfer ratio: {transfer_ratio:.4f}")
# Out:
# Transfer ratio: 0.0403

# %%
by_borough = transfer_df.groupby("borough").agg({
    "ridership": "sum",
    "transfers": "sum"
})

by_borough["transfer_ratio"] = by_borough["transfers"] / by_borough["ridership"]
print(by_borough)
# Out:
#                 ridership  transfers  transfer_ratio
# borough
# Bronx           2052520.0   128804.0        0.062754
# Brooklyn        6471771.0   270383.0        0.041779
# Manhattan      15956255.0   337116.0        0.021128
# Queens          4303180.0   414528.0        0.096331
# Staten Island     51299.0    12642.0        0.246438

# %%
transfer_df = pd.read_csv(os.path.join(DATA_DIR, "mta_random_days_20.csv"))
transfer_df = transfer_df[['borough','ridership','transfers','transit_mode']]
transfer_df
# Out:
#            borough  ridership  transfers transit_mode
# 0            Bronx        2.0        2.0       subway
# 1        Manhattan        3.0        0.0       subway
# 2         Brooklyn        1.0        0.0       subway
# 3           Queens        2.0        1.0       subway
# 4         Brooklyn        1.0        0.0       subway
# ...            ...        ...        ...          ...
# 1401776  Manhattan       32.0        0.0       subway
# 1401777  Manhattan       11.0        1.0       subway
# 1401778  Manhattan       48.0        0.0       subway
# 1401779   Brooklyn        4.0        0.0       subway
# 1401780     Queens        2.0        1.0       subway
#
# [1401781 rows x 4 columns]

# %%
total_ridership = transfer_df["ridership"].sum()
print(f"Total ridership: {total_ridership:.0f}")

double_transfers = 2 * transfer_df["transfers"].sum()
print(f"Double the number of transfers: {double_transfers:.0f}")

transfer_ratio = transfer_df["transfers"].sum() / transfer_df["ridership"].sum()
print(f"Transfer ratio: {transfer_ratio:.4f}")

by_borough = transfer_df.groupby("borough").agg({
    "ridership": "sum",
    "transfers": "sum"
})

by_borough["transfer_ratio"] = by_borough["transfers"] / by_borough["ridership"]
print(by_borough)
# Out:
# Total ridership: 60711820
# Double the number of transfers: 5305980
# Transfer ratio: 0.0437
#                 ridership  transfers  transfer_ratio
# borough
# Bronx           4745923.0   320678.0        0.067569
# Brooklyn       13758432.0   626258.0        0.045518
# Manhattan      32794942.0   733012.0        0.022351
# Queens          9297731.0   944526.0        0.101587
# Staten Island    114792.0    28516.0        0.248415

# %%
#Bus Speed

# %%
# Path to data folder relative to the notebook
DATA_DIR = os.path.join("..", "data", "raw")
bus_evasion_df_2015 = pd.read_csv(os.path.join(DATA_DIR, "MTA_Bus_Speeds__2015-2019_20250819.csv"))
bus_evasion_df_2020 = pd.read_csv(os.path.join(DATA_DIR, "MTA_Bus_Speeds__2020_-_2024_20250819.csv"))
bus_evasion_df_2025 = pd.read_csv(os.path.join(DATA_DIR, "MTA_Bus_Speeds__Beginning_2025.csv"))

# %%
# Append (stack them vertically)
df_bus_speed = pd.concat([bus_evasion_df_2015, bus_evasion_df_2020, bus_evasion_df_2025], ignore_index=True)

# %%
df = df_bus_speed

# %%
'''
# Get the absolute path to the project root
project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))

# Construct the full path to the output file
output_path = os.path.join(project_root, "data", "processed", "df_bus_ridership.csv")

# Save the CSV
df_bus_ridership.to_csv(output_path, index=False)
'''
# Out:
# '\n# Get the absolute path to the project root\nproject_root = os.path.abspath(os.path.join(os.getcwd(), ".."))\n\n# Construct the full path to the output file\noutput_path = os.path.join(project_root, "data", "processed", "df_bus_ridership.csv")\n\n# Save the CSV\ndf_bus_ridership.to_csv(output_path, index=False)\n'

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = df[df["trip_type"] != "EXP"]
# 1. Filter for 'Peak' period and day_type = 1
peak_df = df[(df['period'] == 'Peak') & (df['day_type'] == 1)]

# 2. Group by route_id and calculate average of average_speed
avg_speed_per_route = peak_df.groupby('route_id')['average_speed'].mean().reset_index()

print(avg_speed_per_route)
avg_speed_per_route = avg_speed_per_route[avg_speed_per_route['average_speed'] < 20]

avg_speed_per_route = avg_speed_per_route.reset_index(drop=True)

# 3. Plot histogram
plt.figure(figsize=(10,6))
plt.hist(avg_speed_per_route['average_speed'], bins=20, color='#0077cc', edgecolor='black')
plt.title('Distribution of Average Speeds per Route during Peak (day_type=1)')
plt.xlabel('Average Speed (mph)')
plt.ylabel('Number of Routes')
plt.xlim(0, 20)  # Cut off at 20 mph
plt.grid(axis='y', alpha=0.3)
plt.show()
# Out:
#      route_id  average_speed
# 0          B1       6.738908
# 1        B100       8.900044
# 2    B100SHTL       7.906667
# 3        B103       7.691873
# 4    B103SHTL       9.110385
# ..        ...            ...
# 388   X37SHTL      14.588182
# 389   X38SHTL      11.926667
# 390    X3SHTL      15.330000
# 391    X4SHTL      13.670000
# 392       X68      12.926813
#
# [393 rows x 2 columns]

# %%
df_bus_speed
# Out:
#              month        borough  day_type trip_type route_id    period  \
# 0       2015-01-01          Bronx         1   LCL/LTD      BX1  Off-Peak
# 1       2015-01-01          Bronx         1   LCL/LTD      BX1      Peak
# 2       2015-01-01          Bronx         2   LCL/LTD      BX1  Off-Peak
# 3       2015-01-01          Bronx         2   LCL/LTD      BX1      Peak
# 4       2015-01-01          Bronx         1   LCL/LTD     BX10  Off-Peak
# ...            ...            ...       ...       ...      ...       ...
# 148039  2025-06-01  Staten Island         1       EXP     SIM8      Peak
# 148040  2025-06-01  Staten Island         1       EXP    SIM8X  Off-Peak
# 148041  2025-06-01  Staten Island         1       EXP    SIM8X      Peak
# 148042  2025-06-01  Staten Island         1       EXP     SIM9  Off-Peak
# 148043  2025-06-01  Staten Island         1       EXP     SIM9      Peak
#
#         total_operating_time  total_mileage  average_speed
# 0                    8710307   6.294090e+07       7.230000
# 1                    4334312   3.031650e+07       6.990000
# 2                    2498651   1.874216e+07       7.500000
# 3                    1008139   7.417580e+06       7.360000
# 4                    5778595   5.254381e+07       9.090000
# ...                      ...            ...            ...
# 148039                   496   9.028827e+03      18.178125
# 148040                    58   1.562982e+03      26.591753
# 148041                   214   4.295767e+03      19.989014
# 148042                   238   4.549905e+03      19.113409
# 148043                   308   5.210129e+03      16.868614
#
# [148044 rows x 9 columns]

# %%
# 1. Drop rows where trip_type == "EXP"
df_bus_speed = df_bus_speed[df_bus_speed["trip_type"] != "EXP"]

# 2. Extract year from the "month" column
df_bus_speed["year"] = pd.to_datetime(df_bus_speed["month"]).dt.year

# 3. Group by year and compute SUM(total_mileage)/SUM(total_operating_time)
result = (
    df_bus_speed.groupby("year")
      .apply(lambda g: g["total_mileage"].sum() / g["total_operating_time"].sum())
      .reset_index(name="avg_speed_weighted")
)

print(result)
#2015,2019,2024,2025
# Out:
#     year  avg_speed_weighted
# 0   2015            7.877928
# 1   2016            7.821396
# 2   2017            7.738098
# 3   2018            7.727370
# 4   2019            7.770668
# 5   2020            8.339057
# 6   2021            8.049083
# 7   2022            7.896881
# 8   2023            7.831943
# 9   2024            7.752955
# 10  2025            7.797354
# /var/folders/r2/62xph3kj5rj_w51slp5lpvyc0000gn/T/ipykernel_39244/3827791327.py:10: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(lambda g: g["total_mileage"].sum() / g["total_operating_time"].sum())

# %%
# 1. Drop Express buses
df_bus_speed = df_bus_speed[df_bus_speed["trip_type"] != "EXP"]

# 2. Extract year from "month"
df_bus_speed["year"] = pd.to_datetime(df_bus_speed["month"]).dt.year

# 3. Group by year, day_type, period
result = (
    df_bus_speed
      .groupby(["year", "day_type", "period"])
      .apply(lambda g: g["total_mileage"].sum() / g["total_operating_time"].sum())
      .reset_index(name="avg_speed_weighted")
)

print(result)
# Out:
#     year  day_type    period  avg_speed_weighted
# 0   2015         1  Off-Peak            7.942912
# 1   2015         1      Peak            7.227971
# 2   2015         2  Off-Peak            8.566189
# 3   2015         2      Peak            8.356334
# 4   2016         1  Off-Peak            7.899523
# 5   2016         1      Peak            7.165872
# 6   2016         2  Off-Peak            8.479450
# 7   2016         2      Peak            8.252278
# 8   2017         1  Off-Peak            7.808444
# 9   2017         1      Peak            7.086766
# 10  2017         2  Off-Peak            8.392364
# 11  2017         2      Peak            8.179697
# 12  2018         1  Off-Peak            7.790930
# 13  2018         1      Peak            7.076512
# 14  2018         2  Off-Peak            8.408399
# 15  2018         2      Peak            8.182297
# 16  2019         1  Off-Peak            7.854078
# 17  2019         1      Peak            7.113219
# 18  2019         2  Off-Peak            8.430067
# 19  2019         2      Peak            8.134390
# 20  2020         1  Off-Peak            8.380125
# 21  2020         1      Peak            7.704030
# 22  2020         2  Off-Peak            8.915156
# 23  2020         2      Peak            8.539528
# 24  2021         1  Off-Peak            8.108908
# 25  2021         1      Peak            7.450950
# 26  2021         2  Off-Peak            8.670977
# 27  2021         2      Peak            8.372174
# 28  2022         1  Off-Peak            7.961551
# 29  2022         1      Peak            7.295481
# 30  2022         2  Off-Peak            8.504773
# 31  2022         2      Peak            8.219793
# 32  2023         1  Off-Peak            7.896635
# 33  2023         1      Peak            7.247843
# 34  2023         2  Off-Peak            8.419065
# 35  2023         2      Peak            8.159144
# 36  2024         1  Off-Peak            7.819286
# 37  2024         1      Peak            7.176978
# 38  2024         2  Off-Peak            8.332323
# 39  2024         2      Peak            8.070466
# 40  2025         1  Off-Peak            7.875896
# 41  2025         1      Peak            7.241873
# 42  2025         2  Off-Peak            8.362045
# 43  2025         2      Peak            8.132412
# /var/folders/r2/62xph3kj5rj_w51slp5lpvyc0000gn/T/ipykernel_71327/2274206230.py:11: FutureWarning:
#
# DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.

# %%
# Get the absolute path to the project root
project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))

# Construct the full path to the output file
output_path = os.path.join(project_root, "data", "processed", "result_bus_speeds.csv")

# Save the CSV
result.to_csv(output_path, index=False)

# %%
# 1. Drop Express buses
df_bus_speed = df_bus_speed[df_bus_speed["trip_type"] != "EXP"]

# 2. Extract year from "month"
df_bus_speed["year"] = pd.to_datetime(df_bus_speed["month"]).dt.year

# 3. Group by year, day_type, period
result = (
    df_bus_speed
      .groupby(["year", "borough"])
      .apply(lambda g: g["total_mileage"].sum() / g["total_operating_time"].sum())
      .reset_index(name="avg_speed_weighted")
)

print(result)
# Out:
#     year        borough  avg_speed_weighted
# 0   2015          Bronx            7.224188
# 1   2015       Brooklyn            7.284492
# 2   2015      Manhattan            6.113896
# 3   2015         Queens            9.179244
# 4   2015  Staten Island           12.556208
# 5   2016          Bronx            7.186335
# 6   2016       Brooklyn            7.204761
# 7   2016      Manhattan            6.071632
# 8   2016         Queens            9.085639
# 9   2016  Staten Island           12.384849
# 10  2017          Bronx            7.097764
# 11  2017       Brooklyn            7.121286
# 12  2017      Manhattan            6.067374
# 13  2017         Queens            9.021894
# 14  2017  Staten Island           12.214732
# 15  2018          Bronx            7.086324
# 16  2018       Brooklyn            7.093188
# 17  2018      Manhattan            6.071533
# 18  2018         Queens            8.942544
# 19  2018  Staten Island           12.204445
# 20  2019          Bronx            7.035854
# 21  2019       Brooklyn            7.156340
# 22  2019      Manhattan            6.105185
# 23  2019         Queens            8.740140
# 24  2019  Staten Island           12.277084
# 25  2020          Bronx            7.441658
# 26  2020       Brooklyn            7.661364
# 27  2020      Manhattan            6.728222
# 28  2020         Queens            9.430501
# 29  2020  Staten Island           13.187422
# 30  2021          Bronx            7.218854
# 31  2021       Brooklyn            7.354416
# 32  2021      Manhattan            6.476314
# 33  2021         Queens            9.061696
# 34  2021  Staten Island           12.942839
# 35  2022          Bronx            7.209554
# 36  2022       Brooklyn            7.190176
# 37  2022      Manhattan            6.335582
# 38  2022         Queens            8.873382
# 39  2022  Staten Island           12.736224
# 40  2023          Bronx            7.238727
# 41  2023       Brooklyn            7.116707
# 42  2023      Manhattan            6.265031
# 43  2023         Queens            8.751915
# 44  2023  Staten Island           12.676973
# 45  2024          Bronx            7.175507
# 46  2024       Brooklyn            7.059517
# 47  2024      Manhattan            6.223442
# 48  2024         Queens            8.601059
# 49  2024  Staten Island           12.578909
# 50  2025          Bronx            7.202657
# 51  2025       Brooklyn            7.096030
# 52  2025      Manhattan            6.279721
# 53  2025         Queens            8.631497
# 54  2025  Staten Island           12.476534
# /var/folders/r2/62xph3kj5rj_w51slp5lpvyc0000gn/T/ipykernel_71327/4091971493.py:11: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(lambda g: g["total_mileage"].sum() / g["total_operating_time"].sum())

# %%
import pandas as pd

# 1. Drop Express buses if desired
df_bus_speed = df_bus_speed[df_bus_speed["trip_type"] != "EXP"]

# 2. Extract year
df_bus_speed["year"] = pd.to_datetime(df_bus_speed["month"]).dt.year

# 3. Filter for year 2025, day_type=1, period='Peak'
df_2025_peak = df_bus_speed[
    (df_bus_speed["year"] == 2025) &
    (df_bus_speed["day_type"] == 1) &
    (df_bus_speed["period"] == "Peak")
]

# 4. Group by route_id and compute SUM(total_mileage)/SUM(total_operating_time)
route_speeds = (
    df_2025_peak
    .groupby("route_id")
    .apply(lambda g: g["total_mileage"].sum() / g["total_operating_time"].sum())
    .reset_index(name="avg_speed_peak_2025")
)

print(route_speeds)
# Out:
#     route_id  avg_speed_peak_2025
# 0         B1             6.445145
# 1       B100             8.467177
# 2       B103             7.499862
# 3        B11             5.222681
# 4        B12             5.199290
# ..       ...                  ...
# 268      S92            11.157501
# 269      S93            12.470116
# 270      S94            11.173278
# 271      S96            10.842624
# 272      S98             9.693923
#
# [273 rows x 2 columns]
# /var/folders/r2/62xph3kj5rj_w51slp5lpvyc0000gn/T/ipykernel_71327/376986760.py:20: FutureWarning:
#
# DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.

# %%
# Get the absolute path to the project root
project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))

# Construct the full path to the output file
output_path = os.path.join(project_root, "data", "processed", "speeds_2025peak.csv")

# Save the CSV
route_speeds.to_csv(output_path, index=False)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10,6))
sns.histplot(route_speeds['avg_speed_peak_2025'], bins=15, kde=True, color='skyblue')
plt.axvline(route_speeds['avg_speed_peak_2025'].mean(), color='red', linestyle='--', label='Mean')
plt.xlabel("Average Peak Speed (mph)")
plt.ylabel("Number of Routes")
plt.title("Distribution of NYC Bus Route Speeds (Peak, 2025)")
plt.legend()
plt.show()

# %%
# Define thresholds
thresholds = [5, 7, 9, 11]  # mph

for t in thresholds:
    pct = (route_speeds['avg_speed_peak_2025'] <= t).mean() * 100
    print(f"{pct:.1f}% of routes ≤ {t} mph")
# Out:
# 2.2% of routes ≤ 5 mph
# 49.8% of routes ≤ 7 mph
# 77.3% of routes ≤ 9 mph
# 89.4% of routes ≤ 11 mph

# %%
sorted_speeds = route_speeds['avg_speed_peak_2025'].sort_values()
cum_pct = sorted_speeds.rank(pct=True) * 100

plt.figure(figsize=(10,6))
plt.plot(sorted_speeds, cum_pct, marker='o', linestyle='-')
plt.xlabel("Average Peak Speed (mph)")
plt.ylabel("Cumulative % of Routes")
plt.title("CDF of NYC Bus Route Speeds (Peak, 2025)")
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Define speed bins (mph)
bins = [0, 5, 7, 9, 11, 15]  # adjust as needed
labels = ['≤5 mph', '5-7 mph', '7-9 mph', '9-11 mph', '>11 mph']

route_speeds['speed_bin'] = pd.cut(route_speeds['avg_speed_peak_2025'], bins=bins, labels=labels, right=False)
speed_pct = route_speeds['speed_bin'].value_counts(normalize=True).sort_index() * 100
speed_pct
# Out:
# speed_bin
# ≤5 mph       2.222222
# 5-7 mph     48.148148
# 7-9 mph     27.777778
# 9-11 mph    12.222222
# >11 mph      9.629630
# Name: proportion, dtype: float64

# %%
plt.figure(figsize=(8,6))

# Plot a single stacked bar
bottom = 0
colors = ['#d73027','#fc8d59','#fee08b','#91bfdb','#4575b4']

for i, label in enumerate(speed_pct.index):
    plt.bar('Bus Routes', speed_pct[label], bottom=bottom, color=colors[i], label=label)
    bottom += speed_pct[label]

plt.ylabel("Percentage of Routes (%)")
plt.title("Distribution of NYC Bus Route Speeds (Peak, 2025)")
plt.legend(title="Speed Range")
plt.ylim(0,100)
plt.show()

# %%
#Bus Service

# %%
# Path to data folder relative to the notebook
DATA_DIR = os.path.join("..", "data", "raw")
bus_service_df_2015 = pd.read_csv(os.path.join(DATA_DIR, "MTA_Bus_Service_Delivered__2015-2019_20250819.csv"))
bus_service_df_2020 = pd.read_csv(os.path.join(DATA_DIR, "MTA_Bus_Service_Delivered__2020_-_2024_20250819.csv"))
bus_service_df_2025 = pd.read_csv(os.path.join(DATA_DIR, "MTA_Bus_Service_Delivered__Beginning_2025_20250819.csv"))

# %%
# Append (stack them vertically)
df_bus_service = pd.concat([bus_service_df_2015, bus_service_df_2020, bus_service_df_2025], ignore_index=True)
df_bus_service
# Out:
#             month        borough  day_type trip_type route_id period  \
# 0      2015-01-01          Bronx         1   LCL/LTD      BX1   Peak
# 1      2015-01-01          Bronx         2   LCL/LTD      BX1   Peak
# 2      2015-01-01          Bronx         1   LCL/LTD     BX10   Peak
# 3      2015-01-01          Bronx         2   LCL/LTD     BX10   Peak
# 4      2015-01-01          Bronx         1   LCL/LTD     BX11   Peak
# ...           ...            ...       ...       ...      ...    ...
# 74527  2025-06-01  Staten Island         1       EXP     SIM6   Peak
# 74528  2025-06-01  Staten Island         1       EXP     SIM7   Peak
# 74529  2025-06-01  Staten Island         1       EXP     SIM8   Peak
# 74530  2025-06-01  Staten Island         1       EXP    SIM8X   Peak
# 74531  2025-06-01  Staten Island         1       EXP     SIM9   Peak
#
#        actual_number_of_buses  scheduled_number_of_buses  service_delivered
# 0                         814                        843           0.965599
# 1                         162                        179           0.905028
# 2                         698                        759           0.919631
# 3                         171                        191           0.895288
# 4                         990                       1041           0.951009
# ...                       ...                        ...                ...
# 74527                     661                        801           0.825218
# 74528                     394                        462           0.852814
# 74529                     571                        630           0.906349
# 74530                     193                        253           0.762846
# 74531                     302                        378           0.798942
#
# [74532 rows x 9 columns]

# %%
import pandas as pd

# 1. Filter out Express buses
df_bus_service_local = df_bus_service[df_bus_service["trip_type"] != "EXP"]

# 2. Extract year from month
df_bus_service_local["year"] = pd.to_datetime(df_bus_service_local["month"]).dt.year

# 3. Group by year and compute SUM(scheduled_number_of_buses)/SUM(actual_number_of_buses)
service_ratio_by_year = (
    df_bus_service_local
    .groupby("year")
    .apply(lambda g: g["actual_number_of_buses"].sum() / g["scheduled_number_of_buses"].sum())
    .reset_index(name="scheduled_to_actual_ratio")
)

print(service_ratio_by_year)
# Get the absolute path to the project root
project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))

# Construct the full path to the output file
output_path = os.path.join(project_root, "data", "processed", "service_ratio_by_year.csv")

# Save the CSV
service_ratio_by_year.to_csv(output_path, index=False)
# Out:
#     year  scheduled_to_actual_ratio
# 0   2015                   0.955053
# 1   2016                   0.973157
# 2   2017                   0.973458
# 3   2018                   0.972414
# 4   2019                   0.952244
# 5   2020                   0.945869
# 6   2021                   0.913545
# 7   2022                   0.924251
# 8   2023                   0.929330
# 9   2024                   0.921563
# 10  2025                   0.936000
# /var/folders/r2/62xph3kj5rj_w51slp5lpvyc0000gn/T/ipykernel_71327/594948842.py:7: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/r2/62xph3kj5rj_w51slp5lpvyc0000gn/T/ipykernel_71327/594948842.py:13: FutureWarning:
#
# DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.

# %%
import pandas as pd

# 1. Filter out Express buses
df_bus_service_local = df_bus_service[df_bus_service["trip_type"] != "EXP"]

#Filter for Peak
df_bus_service_local = df_bus_service[df_bus_service["period"] == "Peak"]

# 2. Extract year from month
df_bus_service_local["year"] = pd.to_datetime(df_bus_service_local["month"]).dt.year

# 3. Group by year and compute SUM(scheduled_number_of_buses)/SUM(actual_number_of_buses)
service_ratio_by_year = (
    df_bus_service_local
    .groupby("year")
    .apply(lambda g: g["actual_number_of_buses"].sum() / g["scheduled_number_of_buses"].sum())
    .reset_index(name="scheduled_to_actual_ratio")
)

print(service_ratio_by_year)
# Out:
#     year  scheduled_to_actual_ratio
# 0   2015                   0.955259
# 1   2016                   0.973266
# 2   2017                   0.973415
# 3   2018                   0.970986
# 4   2019                   0.951701
# 5   2020                   0.943254
# 6   2021                   0.911362
# 7   2022                   0.923182
# 8   2023                   0.928781
# 9   2024                   0.920287
# 10  2025                   0.936136
# /var/folders/r2/62xph3kj5rj_w51slp5lpvyc0000gn/T/ipykernel_71327/935029669.py:16: FutureWarning:
#
# DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.

# %%
import pandas as pd

# 1. Filter out Express buses
df_local = df_bus_service[df_bus_service["trip_type"] != "EXP"]

# 2. Extract year from month
df_local["year"] = pd.to_datetime(df_local["month"]).dt.year

df_local = df_local[df_local["year"] > 2024]

# 2. Group by day_type and period
service_ratio_by_day_period = (
    df_local
    .groupby("borough")
    .apply(lambda g: g["actual_number_of_buses"].sum() / g["scheduled_number_of_buses"].sum())
    .reset_index(name="scheduled_to_actual_ratio")
)

print(service_ratio_by_day_period)
# Out:
#          borough  scheduled_to_actual_ratio
# 0          Bronx                   0.923459
# 1       Brooklyn                   0.935649
# 2      Manhattan                   0.942112
# 3         Queens                   0.949719
# 4  Staten Island                   0.883043
# /var/folders/r2/62xph3kj5rj_w51slp5lpvyc0000gn/T/ipykernel_71327/2587905856.py:7: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/r2/62xph3kj5rj_w51slp5lpvyc0000gn/T/ipykernel_71327/2587905856.py:15: FutureWarning:
#
# DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.

# %%
#Bus Wait Assessment
#Wait Assessment measures how evenly buses 
#are spaced.
'''
Wait Assessment (WA) measures how evenly buses are spaced. It is defined as the percentage of actual
intervals between buses that are no more than three minutes over the scheduled interval for the
morning (7 a.m. to 9 a.m.) and afternoon (4 p.m. to 7 p.m.) peak periods and no more than five minutes
over the scheduled interval for the rest of the day (off-peak).
'''

# %%
# Path to data folder relative to the notebook
DATA_DIR = os.path.join("..", "data", "raw")
bus_wait_df_2015 = pd.read_csv(os.path.join(DATA_DIR, "MTA_Bus_Wait_Assessment__2015-2019_20250819.csv"))
bus_wait_df_2020 = pd.read_csv(os.path.join(DATA_DIR, "MTA_Bus_Wait_Assessment__2020_-_2024_20250819.csv"))
bus_wait_df_2025 = pd.read_csv(os.path.join(DATA_DIR, "MTA_Bus_Wait_Assessment__Beginning_2025_20250819.csv"))

# %%
# Append (stack them vertically)
df_bus_wait = pd.concat([bus_wait_df_2015, bus_wait_df_2020, bus_wait_df_2025], ignore_index=True)
df_bus_wait
# Out:
#              month        borough  day_type trip_type route_id    period  \
# 0       2015-01-01          Bronx         1   LCL/LTD      BX1  Off-Peak
# 1       2015-01-01          Bronx         1   LCL/LTD      BX1      Peak
# 2       2015-01-01          Bronx         2   LCL/LTD      BX1  Off-Peak
# 3       2015-01-01          Bronx         2   LCL/LTD      BX1      Peak
# 4       2015-01-01          Bronx         1   LCL/LTD     BX10  Off-Peak
# ...            ...            ...       ...       ...      ...       ...
# 148617  2025-06-01  Staten Island         1       EXP     SIM8      Peak
# 148618  2025-06-01  Staten Island         1       EXP    SIM8X  Off-Peak
# 148619  2025-06-01  Staten Island         1       EXP    SIM8X      Peak
# 148620  2025-06-01  Staten Island         1       EXP     SIM9  Off-Peak
# 148621  2025-06-01  Staten Island         1       EXP     SIM9      Peak
#
#         number_of_trips_passing_wait  number_of_scheduled_trips  \
# 0                              15722                      19586
# 1                               7381                      10468
# 2                               4972                       7774
# 3                               2021                       3304
# 4                              11055                      13678
# ...                              ...                        ...
# 148617                          1207                       1899
# 148618                            24                         51
# 148619                           165                        345
# 148620                           529                        686
# 148621                           437                        995
#
#         wait_assessment
# 0              0.802716
# 1              0.705101
# 2              0.639568
# 3              0.611683
# 4              0.808232
# ...                 ...
# 148617         0.635598
# 148618         0.470588
# 148619         0.478261
# 148620         0.771137
# 148621         0.439196
#
# [148622 rows x 9 columns]

# %%
import pandas as pd

# 1. Filter out Express buses
df_bus_wait = df_bus_wait[df_bus_wait["trip_type"] != "EXP"]

df_bus_wait["month"] = pd.to_datetime(df_bus_wait["month"])
df_bus_wait["year"] = df_bus_wait["month"].dt.year

yearly_wait_assessment = (
    df_bus_wait.groupby("year")
    .agg(
        total_passing=("number_of_trips_passing_wait", "sum"),
        total_scheduled=("number_of_scheduled_trips", "sum")
    )
    .assign(wait_assessment=lambda x: x["total_passing"] / x["total_scheduled"])
    [["wait_assessment"]]  # keep only wait_assessment
    .reset_index()
)

print(yearly_wait_assessment)
# Out:
#     year  wait_assessment
# 0   2015         0.769487
# 1   2016         0.788920
# 2   2017         0.780925
# 3   2018         0.780200
# 4   2019         0.734103
# 5   2020         0.751367
# 6   2021         0.705791
# 7   2022         0.706848
# 8   2023         0.711610
# 9   2024         0.685035
# 10  2025         0.701775

# %%
import pandas as pd

# 1. Filter out Express buses
df_bus_wait = df_bus_wait[df_bus_wait["trip_type"] != "EXP"]

df_bus_wait["month"] = pd.to_datetime(df_bus_wait["month"])
df_bus_wait["year"] = df_bus_wait["month"].dt.year

#df_bus_wait = df_bus_wait[df_bus_wait["year"] > 2024]

yearly_wait_assessment = (
    df_bus_wait.groupby("borough")
    .agg(
        total_passing=("number_of_trips_passing_wait", "sum"),
        total_scheduled=("number_of_scheduled_trips", "sum")
    )
    .assign(wait_assessment=lambda x: x["total_passing"] / x["total_scheduled"])
    [["wait_assessment"]]  # keep only wait_assessment
    .reset_index()
)

print(yearly_wait_assessment)
# Out:
#          borough  wait_assessment
# 0          Bronx         0.742353
# 1       Brooklyn         0.716343
# 2      Manhattan         0.736750
# 3         Queens         0.760162
# 4  Staten Island         0.730874

# %%
import pandas as pd

# 1. Filter out Express buses
df_bus_wait = df_bus_wait[df_bus_wait["trip_type"] != "EXP"]

df_bus_wait["month"] = pd.to_datetime(df_bus_wait["month"])
df_bus_wait["year"] = df_bus_wait["month"].dt.year

#df_bus_wait = df_bus_wait[df_bus_wait["year"] > 2024]

yearly_wait_assessment = (
    df_bus_wait.groupby(["borough","day_type"])
    .agg(
        total_passing=("number_of_trips_passing_wait", "sum"),
        total_scheduled=("number_of_scheduled_trips", "sum")
    )
    .assign(wait_assessment=lambda x: x["total_passing"] / x["total_scheduled"])
    [["wait_assessment"]]  # keep only wait_assessment
    .reset_index()
)

print(yearly_wait_assessment)
# Out:
#          borough  day_type  wait_assessment
# 0          Bronx         1         0.734006
# 1          Bronx         2         0.768737
# 2       Brooklyn         1         0.715121
# 3       Brooklyn         2         0.719817
# 4      Manhattan         1         0.736338
# 5      Manhattan         2         0.737949
# 6         Queens         1         0.756313
# 7         Queens         2         0.772948
# 8  Staten Island         1         0.728860
# 9  Staten Island         2         0.738296

# %%
import pandas as pd

# 1. Filter out Express buses
df_bus_wait = df_bus_wait[df_bus_wait["trip_type"] != "EXP"]

df_bus_wait["month"] = pd.to_datetime(df_bus_wait["month"])
df_bus_wait["year"] = df_bus_wait["month"].dt.year

#df_bus_wait = df_bus_wait[df_bus_wait["year"] > 2024]

yearly_wait_assessment = (
    df_bus_wait.groupby(["borough","period"])
    .agg(
        total_passing=("number_of_trips_passing_wait", "sum"),
        total_scheduled=("number_of_scheduled_trips", "sum")
    )
    .assign(wait_assessment=lambda x: x["total_passing"] / x["total_scheduled"])
    [["wait_assessment"]]  # keep only wait_assessment
    .reset_index()
)

print(yearly_wait_assessment)
# Out:
#          borough    period  wait_assessment
# 0          Bronx  Off-Peak         0.767753
# 1          Bronx      Peak         0.689072
# 2       Brooklyn  Off-Peak         0.736960
# 3       Brooklyn      Peak         0.668793
# 4      Manhattan  Off-Peak         0.755679
# 5      Manhattan      Peak         0.693495
# 6         Queens  Off-Peak         0.789333
# 7         Queens      Peak         0.698212
# 8  Staten Island  Off-Peak         0.761402
# 9  Staten Island      Peak         0.665657

# %%
import pandas as pd

# 1. Filter out Express buses
df_bus_wait = df_bus_wait[df_bus_wait["trip_type"] != "EXP"]

df_bus_wait["month"] = pd.to_datetime(df_bus_wait["month"])
df_bus_wait["year"] = df_bus_wait["month"].dt.year

#df_bus_wait = df_bus_wait[df_bus_wait["year"] > 2024]

yearly_wait_assessment = (
    df_bus_wait.groupby(["year","day_type"])
    .agg(
        total_passing=("number_of_trips_passing_wait", "sum"),
        total_scheduled=("number_of_scheduled_trips", "sum")
    )
    .assign(wait_assessment=lambda x: x["total_passing"] / x["total_scheduled"])
    [["wait_assessment"]]  # keep only wait_assessment
    .reset_index()
)

print(yearly_wait_assessment)
# Out:
#     year  day_type  wait_assessment
# 0   2015         1         0.771097
# 1   2015         2         0.764311
# 2   2016         1         0.783355
# 3   2016         2         0.806350
# 4   2017         1         0.775375
# 5   2017         2         0.798174
# 6   2018         1         0.773760
# 7   2018         2         0.800380
# 8   2019         1         0.730854
# 9   2019         2         0.744225
# 10  2020         1         0.747040
# 11  2020         2         0.764388
# 12  2021         1         0.701753
# 13  2021         2         0.718356
# 14  2022         1         0.703923
# 15  2022         2         0.715750
# 16  2023         1         0.709833
# 17  2023         2         0.717045
# 18  2024         1         0.683215
# 19  2024         2         0.690622
# 20  2025         1         0.702114
# 21  2025         2         0.700647

# %%
import pandas as pd

# 1. Filter out Express buses
df_bus_wait = df_bus_wait[df_bus_wait["trip_type"] != "EXP"]

df_bus_wait["month"] = pd.to_datetime(df_bus_wait["month"])
df_bus_wait["year"] = df_bus_wait["month"].dt.year

#df_bus_wait = df_bus_wait[df_bus_wait["year"] > 2024]

yearly_wait_assessment = (
    df_bus_wait.groupby(["year","period"])
    .agg(
        total_passing=("number_of_trips_passing_wait", "sum"),
        total_scheduled=("number_of_scheduled_trips", "sum")
    )
    .assign(wait_assessment=lambda x: x["total_passing"] / x["total_scheduled"])
    [["wait_assessment"]]  # keep only wait_assessment
    .reset_index()
)

print(yearly_wait_assessment)

# Get the absolute path to the project root
project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))

# Construct the full path to the output file
output_path = os.path.join(project_root, "data", "processed", "yearly_wait_assessment.csv")

# Save the CSV
yearly_wait_assessment.to_csv(output_path, index=False)
# Out:
#     year    period  wait_assessment
# 0   2015  Off-Peak         0.796253
# 1   2015      Peak         0.712001
# 2   2016  Off-Peak         0.815980
# 3   2016      Peak         0.731021
# 4   2017  Off-Peak         0.809243
# 5   2017      Peak         0.720225
# 6   2018  Off-Peak         0.807602
# 7   2018      Peak         0.721704
# 8   2019  Off-Peak         0.760404
# 9   2019      Peak         0.676234
# 10  2020  Off-Peak         0.771830
# 11  2020      Peak         0.704274
# 12  2021  Off-Peak         0.727447
# 13  2021      Peak         0.657673
# 14  2022  Off-Peak         0.730398
# 15  2022      Peak         0.654827
# 16  2023  Off-Peak         0.734811
# 17  2023      Peak         0.660279
# 18  2024  Off-Peak         0.707327
# 19  2024      Peak         0.635851
# 20  2025  Off-Peak         0.723665
# 21  2025      Peak         0.653792

# %%
#Mean Distance Between repair

# %%
# Path to data folder relative to the notebook
DATA_DIR = os.path.join("..", "data", "raw")
bus_repair_df_2015 = pd.read_csv(os.path.join(DATA_DIR, "MTA_Bus_Mean_Distance_Between_Failures__Beginning_2015_20250819.csv"))

#data/raw/MTA_Bus_Mean_Distance_Between_Failures__Beginning_2015_20250819.csv

# %%
bus_repair_df_2015
# Out:
#           Month        Borough  Monthly Miles  Monthly Road Call Count  \
# 0    06/01/2025          Bronx        2091977                      978
# 1    06/01/2025       Brooklyn        2776380                      709
# 2    06/01/2025      Manhattan        1281985                      514
# 3    06/01/2025         Queens        4246399                      822
# 4    06/01/2025  Staten Island        2146532                      362
# ..          ...            ...            ...                      ...
# 625  01/01/2015          Bronx        2166371                      434
# 626  01/01/2015       Brooklyn        2901602                      576
# 627  01/01/2015      Manhattan        1283763                      458
# 628  01/01/2015         Queens        4032200                      810
# 629  01/01/2015  Staten Island        2029610                      230
#
#      Monthly MDBF
# 0            2139
# 1            3916
# 2            2494
# 3            5166
# 4            5930
# ..            ...
# 625          4992
# 626          5038
# 627          2803
# 628          4978
# 629          8824
#
# [630 rows x 5 columns]

# %%
import pandas as pd

# ensure Month is datetime
bus_repair_df_2015["Month"] = pd.to_datetime(bus_repair_df_2015["Month"])

# extract year
bus_repair_df_2015["year"] = bus_repair_df_2015["Month"].dt.year

# group by year and compute average MDBF
yearly_mdbf = (
    bus_repair_df_2015.groupby("year")["Monthly MDBF"]
    .agg(total_mdbf="sum", months="count")
    .assign(Annual_MDBF=lambda x: x["total_mdbf"] / x["months"])
    [["Annual_MDBF"]]
    .reset_index()
)

print(yearly_mdbf)

# Get the absolute path to the project root
project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))

# Construct the full path to the output file
output_path = os.path.join(project_root, "data", "processed", "yearly_mdbf.csv")

# Save the CSV
yearly_mdbf.to_csv(output_path, index=False)
# Out:
#     year   Annual_MDBF
# 0   2015   5316.583333
# 1   2016   8442.683333
# 2   2017   8839.633333
# 3   2018   8468.316667
# 4   2019   9753.433333
# 5   2020  11348.216667
# 6   2021   9886.000000
# 7   2022   9113.083333
# 8   2023   8965.700000
# 9   2024   8085.716667
# 10  2025   6627.433333

# %%
import pandas as pd

# ensure Month is datetime
bus_repair_df_2015["Month"] = pd.to_datetime(bus_repair_df_2015["Month"])

# extract year
bus_repair_df_2015["year"] = bus_repair_df_2015["Month"].dt.year

# group by year & borough
borough_yearly_mdbf = (
    bus_repair_df_2015.groupby("Borough")["Monthly MDBF"]
    .agg(total_mdbf="sum", months="count")
    .assign(Annual_MDBF=lambda x: x["total_mdbf"] / x["months"])
    [["Annual_MDBF"]]
    .reset_index()
)

print(borough_yearly_mdbf.head())
# Out:
#          Borough   Annual_MDBF
# 0          Bronx   4914.595238
# 1       Brooklyn   7129.325397
# 2      Manhattan   4179.301587
# 3         Queens   7117.071429
# 4  Staten Island  20246.888889

# %%
import pandas as pd

# make sure Month is datetime
bus_repair_df_2015["Month"] = pd.to_datetime(bus_repair_df_2015["Month"])
bus_repair_df_2015["year"] = bus_repair_df_2015["Month"].dt.year

# filter for 2024 and 2025
df_24_25 = bus_repair_df_2015[bus_repair_df_2015["year"].between(2024, 2025)]

# group by borough, sum & count months, then divide
mdbf_24_25 = (
    df_24_25.groupby("Borough")["Monthly MDBF"]
    .agg(total_mdbf="sum", months="count")
    .assign(Average_MDBF=lambda x: x["total_mdbf"] / x["months"])
    [["Average_MDBF"]]
    .reset_index()
)

print(mdbf_24_25)
# Out:
#          Borough  Average_MDBF
# 0          Bronx   3642.055556
# 1       Brooklyn   5680.833333
# 2      Manhattan   3910.111111
# 3         Queens   7661.111111
# 4  Staten Island  17104.000000

# %%
#MTA BUS CUSTOMER METRICS
#additional_bus_stop_time	additional_travel_time	customer_journey_time_performance
import os
import pandas as pd

# %%
# Path to data folder relative to the notebook
DATA_DIR = os.path.join("..", "data", "raw")
bus_jrny_df_2017 = pd.read_csv(os.path.join(DATA_DIR, "MTA_Bus_Customer_Journey-Focused_Metrics__2017-2019_20250819.csv"))
bus_jrny_df_2020 = pd.read_csv(os.path.join(DATA_DIR, "MTA_Bus_Customer_Journey-Focused_Metrics__2020_-_2024_20250819.csv"))
bus_jrny_df_2025 = pd.read_csv(os.path.join(DATA_DIR, "MTA_Bus_Customer_Journey-Focused_Metrics__Beginning_2025_20250819.csv"))

# %%
# Append (stack them vertically)
df_bus_jrny = pd.concat([bus_jrny_df_2017, bus_jrny_df_2020, bus_jrny_df_2025], ignore_index=True)
#df_bus_jrny

# %%
import pandas as pd

# Make sure 'month' is datetime and extract year
df_bus_jrny['month'] = pd.to_datetime(df_bus_jrny['month'])
df_bus_jrny['year'] = df_bus_jrny['month'].dt.year

# Filter out EXP trip_type
df_filtered = df_bus_jrny[df_bus_jrny['trip_type'] != "EXP"]

# Group by year, route_id, period and calculate averages
df_grouped = df_filtered.groupby(['year', 'period'], as_index=False)[
    ['number_of_customers', 'additional_bus_stop_time', 'additional_travel_time', 'customer_journey_time_performance']
].mean()

# Display the result
print(df_grouped.head())
# Out:
#    year    period  number_of_customers  additional_bus_stop_time  \
# 0  2017  Off-Peak        108364.655583                  2.119318
# 1  2017      Peak         76726.351820                  2.038157
# 2  2018  Off-Peak        102865.313662                  2.018835
# 3  2018      Peak         72832.644639                  1.929235
# 4  2019  Off-Peak        115359.384304                  2.425199
#
#    additional_travel_time  customer_journey_time_performance
# 0                0.807216                           0.712292
# 1                1.063461                           0.689922
# 2                0.668189                           0.726592
# 3                0.867517                           0.707845
# 4                1.015988                           0.697352

# %%
import matplotlib.pyplot as plt

# Map periods to Peak/Off-Peak
df_grouped['peak_type'] = df_grouped['period'].apply(lambda x: 'Peak' if 'Peak' in x else 'Off-Peak')

# Aggregate across route_id and period type
df_peak_offpeak = df_grouped.groupby(['year', 'peak_type'], as_index=False)[
    ['number_of_customers', 'additional_bus_stop_time', 'additional_travel_time', 'customer_journey_time_performance']
].mean()

# Function to plot metric for Peak vs Off-Peak
def plot_peak_offpeak(df, metric, title):
    plt.figure(figsize=(8,5))
    for pt in ['Peak', 'Off-Peak']:
        subset = df[df['peak_type'] == pt]
        plt.plot(subset['year'], subset[metric], marker='o', label=pt)
    
    plt.title(title)
    plt.xlabel("Year")
    plt.ylabel(metric.replace("_", " ").title())
    plt.legend(title="Period Type")
    plt.grid(True, alpha=0.3)
    plt.show()

# Plot each metric
plot_peak_offpeak(df_peak_offpeak, 'number_of_customers', 'Average Number of Customers: Peak vs Off-Peak')
plot_peak_offpeak(df_peak_offpeak, 'additional_bus_stop_time', 'Average Additional Bus Stop Time: Peak vs Off-Peak')
plot_peak_offpeak(df_peak_offpeak, 'additional_travel_time', 'Average Additional Travel Time: Peak vs Off-Peak')
plot_peak_offpeak(df_peak_offpeak, 'customer_journey_time_performance', 'Average Customer Journey Performance: Peak vs Off-Peak')

# %%
'''
import pandas as pd

# Ensure month is datetime and extract year
# 1. Filter out Express buses
df_bus_jrny = df_bus_jrny[df_bus_jrny["trip_type"] != "EXP"]
df_bus_jrny['month'] = pd.to_datetime(df_bus_jrny['month'])
df_bus_jrny['year'] = df_bus_jrny['month'].dt.year

# Filter for 2025
df_2025 = df_bus_jrny[df_bus_jrny['year'] == 2025]

# Group by route_id and average the selected columns
df_2025_grouped = df_2025.groupby('route_id', as_index=False)[
    ['number_of_customers', 'additional_bus_stop_time', 'additional_travel_time', 'customer_journey_time_performance']
].mean()

# Display
print(df_2025_grouped)
'''
# Out:
# '\nimport pandas as pd\n\n# Ensure month is datetime and extract year\n# 1. Filter out Express buses\ndf_bus_jrny = df_bus_jrny[df_bus_jrny["trip_type"] != "EXP"]\ndf_bus_jrny[\'month\'] = pd.to_datetime(df_bus_jrny[\'month\'])\ndf_bus_jrny[\'year\'] = df_bus_jrny[\'month\'].dt.year\n\n# Filter for 2025\ndf_2025 = df_bus_jrny[df_bus_jrny[\'year\'] == 2025]\n\n# Group by route_id and average the selected columns\ndf_2025_grouped = df_2025.groupby(\'route_id\', as_index=False)[\n    [\'number_of_customers\', \'additional_bus_stop_time\', \'additional_travel_time\', \'customer_journey_time_performance\']\n].mean()\n\n# Display\nprint(df_2025_grouped)\n'

# %%
'''
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))

# Scatter plot
plt.scatter(
    df_bus_stop_cust['additional_bus_stop_time'],
    df_bus_stop_cust['number_of_customers'],
    alpha=0.7
)

plt.xlabel("Additional Bus Stop Time (minutes)")
plt.ylabel("Number of Customers (avg)")
plt.title("Scatter Plot: Bus Stop Time vs. Number of Customers (2025)")

plt.show()
'''
# Out:
# '\nimport matplotlib.pyplot as plt\n\nplt.figure(figsize=(10, 6))\n\n# Scatter plot\nplt.scatter(\n    df_bus_stop_cust[\'additional_bus_stop_time\'],\n    df_bus_stop_cust[\'number_of_customers\'],\n    alpha=0.7\n)\n\nplt.xlabel("Additional Bus Stop Time (minutes)")\nplt.ylabel("Number of Customers (avg)")\nplt.title("Scatter Plot: Bus Stop Time vs. Number of Customers (2025)")\n\nplt.show()\n'

# %%
'''
# DataFrame for additional_bus_stop_time
df_bus_stop_cust = df_2025_grouped[['route_id', 'additional_bus_stop_time','number_of_customers']]
#print(df_bus_stop_cust)

# DataFrame for additional_travel_time
df_travel_cust = df_2025_grouped[['route_id', 'additional_travel_time','number_of_customers']]
#print(df_travel_cust)

# DataFrame for customer_journey_time_performance
df_journey_cust = df_2025_grouped[['route_id', 'customer_journey_time_performance','number_of_customers']]
#print(df_journey_cust)
'''
# Out:
# "\n# DataFrame for additional_bus_stop_time\ndf_bus_stop_cust = df_2025_grouped[['route_id', 'additional_bus_stop_time','number_of_customers']]\n#print(df_bus_stop_cust)\n\n# DataFrame for additional_travel_time\ndf_travel_cust = df_2025_grouped[['route_id', 'additional_travel_time','number_of_customers']]\n#print(df_travel_cust)\n\n# DataFrame for customer_journey_time_performance\ndf_journey_cust = df_2025_grouped[['route_id', 'customer_journey_time_performance','number_of_customers']]\n#print(df_journey_cust)\n"

# %%
'''
import matplotlib.pyplot as plt

# Pivot the dataframe so routes are rows and years are columns
df_scatter = df_bus_stop_cust.pivot(index="route_id", columns="year", values="additional_bus_stop_time").dropna()

plt.figure(figsize=(8, 6))

# Scatter: x = 2017 values, y = 2025 values
plt.scatter(df_scatter[2017], df_scatter[2025], alpha=0.7)

# Add 45-degree reference line
lims = [
    min(df_scatter.min()), 
    max(df_scatter.max())
]
plt.plot(lims, lims, 'r--', alpha=0.8)

plt.xlabel("2017 Additional Bus Stop Time")
plt.ylabel("2025 Additional Bus Stop Time")
plt.title("Scatter Plot of Additional Bus Stop Time (2017 vs 2025)")
plt.show()
'''
# Out:
# '\nimport matplotlib.pyplot as plt\n\n# Pivot the dataframe so routes are rows and years are columns\ndf_scatter = df_bus_stop_cust.pivot(index="route_id", columns="year", values="additional_bus_stop_time").dropna()\n\nplt.figure(figsize=(8, 6))\n\n# Scatter: x = 2017 values, y = 2025 values\nplt.scatter(df_scatter[2017], df_scatter[2025], alpha=0.7)\n\n# Add 45-degree reference line\nlims = [\n    min(df_scatter.min()), \n    max(df_scatter.max())\n]\nplt.plot(lims, lims, \'r--\', alpha=0.8)\n\nplt.xlabel("2017 Additional Bus Stop Time")\nplt.ylabel("2025 Additional Bus Stop Time")\nplt.title("Scatter Plot of Additional Bus Stop Time (2017 vs 2025)")\nplt.show()\n'

# %%
'''
# Ensure 'month' is datetime
df_bus_jrny['month'] = pd.to_datetime(df_bus_jrny['month'])

# 1. Filter out Express buses
df_bus_jrny = df_bus_jrny[df_bus_jrny["trip_type"] != "EXP"]

# Extract year
df_bus_jrny['year'] = df_bus_jrny['month'].dt.year

# Filter for 2017 and 2025
df_filtered = df_bus_jrny[df_bus_jrny['year'].isin([2017, 2025])]

# Group by year and route_id and calculate averages
df_grouped = df_filtered.groupby(['year', 'route_id'], as_index=False)[
    ['additional_bus_stop_time', 'additional_travel_time', 'customer_journey_time_performance']
].mean()

# Display result
#print(df_grouped)

# DataFrame for additional_bus_stop_time
df_bus_stop = df_grouped[['year', 'route_id', 'additional_bus_stop_time']]
print(df_bus_stop)

# DataFrame for additional_travel_time
df_travel = df_grouped[['year', 'route_id', 'additional_travel_time']]
#print(df_travel)

# DataFrame for customer_journey_time_performance
df_journey = df_grouped[['year', 'route_id', 'customer_journey_time_performance']]
#print(df_journey)
'''
# Out:
# '\n# Ensure \'month\' is datetime\ndf_bus_jrny[\'month\'] = pd.to_datetime(df_bus_jrny[\'month\'])\n\n# 1. Filter out Express buses\ndf_bus_jrny = df_bus_jrny[df_bus_jrny["trip_type"] != "EXP"]\n\n# Extract year\ndf_bus_jrny[\'year\'] = df_bus_jrny[\'month\'].dt.year\n\n# Filter for 2017 and 2025\ndf_filtered = df_bus_jrny[df_bus_jrny[\'year\'].isin([2017, 2025])]\n\n# Group by year and route_id and calculate averages\ndf_grouped = df_filtered.groupby([\'year\', \'route_id\'], as_index=False)[\n    [\'additional_bus_stop_time\', \'additional_travel_time\', \'customer_journey_time_performance\']\n].mean()\n\n# Display result\n#print(df_grouped)\n\n# DataFrame for additional_bus_stop_time\ndf_bus_stop = df_grouped[[\'year\', \'route_id\', \'additional_bus_stop_time\']]\nprint(df_bus_stop)\n\n# DataFrame for additional_travel_time\ndf_travel = df_grouped[[\'year\', \'route_id\', \'additional_travel_time\']]\n#print(df_travel)\n\n# DataFrame for customer_journey_time_performance\ndf_journey = df_grouped[[\'year\', \'route_id\', \'customer_journey_time_performance\']]\n#print(df_journey)\n'

# %%
'''
import matplotlib.pyplot as plt

# Define a helper function for histograms
def plot_hist(df, column, title):
    plt.figure(figsize=(8, 5))

    # Plot histograms for 2017 and 2025
    plt.hist(
        df[df['year'] == 2017][column],
        bins=30, alpha=0.6, label="2017"
    )
    plt.hist(
        df[df['year'] == 2025][column],
        bins=30, alpha=0.6, label="2025"
    )

    plt.title(title)
    plt.xlabel(column.replace("_", " ").title())
    plt.ylabel("Frequency")
    plt.legend()
    plt.show()


# Plot for each metric
#plot_hist(df_bus_stop, "additional_bus_stop_time", "Additional Bus Stop Time (2017 vs 2025)")
#plot_hist(df_travel, "additional_travel_time", "Additional Travel Time (2017 vs 2025)")
#plot_hist(df_journey, "customer_journey_time_performance", "Customer Journey Time Performance (2017 vs 2025)")
'''
# Out:
# '\nimport matplotlib.pyplot as plt\n\n# Define a helper function for histograms\ndef plot_hist(df, column, title):\n    plt.figure(figsize=(8, 5))\n\n    # Plot histograms for 2017 and 2025\n    plt.hist(\n        df[df[\'year\'] == 2017][column],\n        bins=30, alpha=0.6, label="2017"\n    )\n    plt.hist(\n        df[df[\'year\'] == 2025][column],\n        bins=30, alpha=0.6, label="2025"\n    )\n\n    plt.title(title)\n    plt.xlabel(column.replace("_", " ").title())\n    plt.ylabel("Frequency")\n    plt.legend()\n    plt.show()\n\n\n# Plot for each metric\n#plot_hist(df_bus_stop, "additional_bus_stop_time", "Additional Bus Stop Time (2017 vs 2025)")\n#plot_hist(df_travel, "additional_travel_time", "Additional Travel Time (2017 vs 2025)")\n#plot_hist(df_journey, "customer_journey_time_performance", "Customer Journey Time Performance (2017 vs 2025)")\n'

# %%
'''
import matplotlib.pyplot as plt

# Pivot the dataframe so routes are rows and years are columns
df_scatter = df_bus_stop.pivot(index="route_id", columns="year", values="additional_bus_stop_time").dropna()

plt.figure(figsize=(8, 6))

# Scatter: x = 2017 values, y = 2025 values
plt.scatter(df_scatter[2017], df_scatter[2025], alpha=0.7)

# Add 45-degree reference line
lims = [
    min(df_scatter.min()), 
    max(df_scatter.max())
]
plt.plot(lims, lims, 'r--', alpha=0.8)

plt.xlabel("2017 Additional Bus Stop Time")
plt.ylabel("2025 Additional Bus Stop Time")
plt.title("Scatter Plot of Additional Bus Stop Time (2017 vs 2025)")
plt.show()
'''
# Out:
# '\nimport matplotlib.pyplot as plt\n\n# Pivot the dataframe so routes are rows and years are columns\ndf_scatter = df_bus_stop.pivot(index="route_id", columns="year", values="additional_bus_stop_time").dropna()\n\nplt.figure(figsize=(8, 6))\n\n# Scatter: x = 2017 values, y = 2025 values\nplt.scatter(df_scatter[2017], df_scatter[2025], alpha=0.7)\n\n# Add 45-degree reference line\nlims = [\n    min(df_scatter.min()), \n    max(df_scatter.max())\n]\nplt.plot(lims, lims, \'r--\', alpha=0.8)\n\nplt.xlabel("2017 Additional Bus Stop Time")\nplt.ylabel("2025 Additional Bus Stop Time")\nplt.title("Scatter Plot of Additional Bus Stop Time (2017 vs 2025)")\nplt.show()\n'

# %%
'''
import matplotlib.pyplot as plt

# Pivot the dataframe so routes are rows and years are columns
df_scatter = df_travel.pivot(index="route_id", columns="year", values="additional_travel_time").dropna()

plt.figure(figsize=(8, 6))

# Scatter: x = 2017 values, y = 2025 values
plt.scatter(df_scatter[2017], df_scatter[2025], alpha=0.7)

# Add 45-degree reference line
lims = [
    min(df_scatter.min()), 
    max(df_scatter.max())
]
plt.plot(lims, lims, 'r--', alpha=0.8)

plt.xlabel("2017 Additional Bus Stop Time")
plt.ylabel("2025 Additional Bus Stop Time")
plt.title("Scatter Plot of Additional Bus Stop Time (2017 vs 2025)")
plt.show()
'''
# Out:
# '\nimport matplotlib.pyplot as plt\n\n# Pivot the dataframe so routes are rows and years are columns\ndf_scatter = df_travel.pivot(index="route_id", columns="year", values="additional_travel_time").dropna()\n\nplt.figure(figsize=(8, 6))\n\n# Scatter: x = 2017 values, y = 2025 values\nplt.scatter(df_scatter[2017], df_scatter[2025], alpha=0.7)\n\n# Add 45-degree reference line\nlims = [\n    min(df_scatter.min()), \n    max(df_scatter.max())\n]\nplt.plot(lims, lims, \'r--\', alpha=0.8)\n\nplt.xlabel("2017 Additional Bus Stop Time")\nplt.ylabel("2025 Additional Bus Stop Time")\nplt.title("Scatter Plot of Additional Bus Stop Time (2017 vs 2025)")\nplt.show()\n'

# %%
'''
import matplotlib.pyplot as plt

# Pivot the dataframe so routes are rows and years are columns
df_scatter = df_bus_stop.pivot(index="route_id", columns="year", values="additional_bus_stop_time").dropna()

plt.figure(figsize=(8, 6))

# Scatter: x = 2017 values, y = 2025 values
plt.scatter(df_scatter[2017], df_scatter[2025], alpha=0.7)

# Add 45-degree reference line
lims = [
    min(df_scatter.min()), 
    max(df_scatter.max())
]
plt.plot(lims, lims, 'r--', alpha=0.8)

plt.xlabel("2017 Additional Bus Stop Time")
plt.ylabel("2025 Additional Bus Stop Time")
plt.title("Scatter Plot of Additional Bus Stop Time (2017 vs 2025)")
plt.show()
'''
# Out:
# '\nimport matplotlib.pyplot as plt\n\n# Pivot the dataframe so routes are rows and years are columns\ndf_scatter = df_bus_stop.pivot(index="route_id", columns="year", values="additional_bus_stop_time").dropna()\n\nplt.figure(figsize=(8, 6))\n\n# Scatter: x = 2017 values, y = 2025 values\nplt.scatter(df_scatter[2017], df_scatter[2025], alpha=0.7)\n\n# Add 45-degree reference line\nlims = [\n    min(df_scatter.min()), \n    max(df_scatter.max())\n]\nplt.plot(lims, lims, \'r--\', alpha=0.8)\n\nplt.xlabel("2017 Additional Bus Stop Time")\nplt.ylabel("2025 Additional Bus Stop Time")\nplt.title("Scatter Plot of Additional Bus Stop Time (2017 vs 2025)")\nplt.show()\n'

# %%
import pandas as pd
import warnings
warnings.simplefilter(action="ignore", category=pd.errors.SettingWithCopyWarning)


# 1. Filter out Express buses
df_bus_jrny = df_bus_jrny[df_bus_jrny["trip_type"] != "EXP"]

# make sure month is datetime
df_bus_jrny["month"] = pd.to_datetime(df_bus_jrny["month"])

# extract year
df_bus_jrny["year"] = df_bus_jrny["month"].dt.year

# group by year and compute averages
yearly_journey_perf = (
    df_bus_jrny.groupby("year")
    .agg(
        additional_bus_stop_time_sum=("additional_bus_stop_time", "sum"),
        additional_travel_time_sum=("additional_travel_time", "sum"),
        customer_journey_time_performance_sum=("customer_journey_time_performance", "sum"),
        records=("month", "count")
    )
    .assign(
        avg_additional_bus_stop_time=lambda x: x["additional_bus_stop_time_sum"] / x["records"],
        avg_additional_travel_time=lambda x: x["additional_travel_time_sum"] / x["records"],
        avg_customer_journey_time_performance=lambda x: x["customer_journey_time_performance_sum"] / x["records"]
    )
    [["avg_additional_bus_stop_time", "avg_additional_travel_time", "avg_customer_journey_time_performance"]]
    .reset_index()
)

print(yearly_journey_perf)

yearly_journey_perf['avg_additional_time'] = yearly_journey_perf['avg_additional_bus_stop_time'] + yearly_journey_perf['avg_additional_travel_time']

#print(yearly_journey_perf)
# Out:
#    year  avg_additional_bus_stop_time  avg_additional_travel_time  \
# 0  2017                      2.078737                    0.935338
# 1  2018                      1.974035                    0.767853
# 2  2019                      2.407678                    1.110827
# 3  2020                      2.257264                    0.173992
# 4  2021                      2.873868                    0.227701
# 5  2022                      2.790826                    0.674259
# 6  2023                      2.695352                    0.786603
# 7  2024                      3.081756                    0.941573
# 8  2025                      2.779832                    0.808098
#
#    avg_customer_journey_time_performance
# 0                               0.701107
# 1                               0.717219
# 2                               0.686959
# 3                               0.753014
# 4                               0.729350
# 5                               0.700642
# 6                               0.695601
# 7                               0.668256
# 8                               0.686549

# %%
print(yearly_journey_perf)
# Out:
#    year  avg_additional_bus_stop_time  avg_additional_travel_time  \
# 0  2017                      2.078737                    0.935338
# 1  2018                      1.974035                    0.767853
# 2  2019                      2.407678                    1.110827
# 3  2020                      2.257264                    0.173992
# 4  2021                      2.873868                    0.227701
# 5  2022                      2.790826                    0.674259
# 6  2023                      2.695352                    0.786603
# 7  2024                      3.081756                    0.941573
# 8  2025                      2.779832                    0.808098
#
#    avg_customer_journey_time_performance  avg_additional_time
# 0                               0.701107             3.014076
# 1                               0.717219             2.741888
# 2                               0.686959             3.518505
# 3                               0.753014             2.431256
# 4                               0.729350             3.101569
# 5                               0.700642             3.465084
# 6                               0.695601             3.481955
# 7                               0.668256             4.023328
# 8                               0.686549             3.587930

# %%
yearly_journey_bus_stop_time = yearly_journey_perf[['year','avg_additional_bus_stop_time']]
yearly_journey_bus_add_time = yearly_journey_perf[['year','avg_additional_travel_time']]
yearly_journey_bus_total_time = yearly_journey_perf[['year','avg_additional_time']]
yearly_journey_bus_journey_5 = yearly_journey_perf[['year','avg_customer_journey_time_performance']]

# %%
#yearly_journey_bus_stop_time
# Get the absolute path to the project root
project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))

# Construct the full path to the output file
output_path = os.path.join(project_root, "data", "processed", "yearly_journey_bus_stop_time.csv")

# Save the CSV
yearly_journey_bus_stop_time.to_csv(output_path, index=False)


#yearly_journey_bus_add_time
# Get the absolute path to the project root
project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))

# Construct the full path to the output file
output_path = os.path.join(project_root, "data", "processed", "yearly_journey_bus_add_time.csv")

# Save the CSV
yearly_journey_bus_add_time.to_csv(output_path, index=False)


#yearly_journey_bus_total_time
# Get the absolute path to the project root
project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))

# Construct the full path to the output file
output_path = os.path.join(project_root, "data", "processed", "yearly_journey_bus_total_time.csv")

# Save the CSV
yearly_journey_bus_total_time.to_csv(output_path, index=False)


#yearly_journey_bus_journey_5
# Get the absolute path to the project root
project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))

# Construct the full path to the output file
output_path = os.path.join(project_root, "data", "processed", "yearly_journey_bus_journey_5.csv")

# Save the CSV
yearly_journey_bus_journey_5.to_csv(output_path, index=False)

# %%
'''
# 1. Filter out Express buses
import pandas as pd
import numpy as np

df = df_bus_jrny

# Aggregate total ridership per route
route_totals = df.groupby("route_id")["number_of_customers"].sum().sort_values(ascending=False)
top_routes = route_totals.head(7).index.tolist()

# Filter only top 7 routes
df_top = df[df["route_id"].isin(top_routes)]

# Aggregate monthly total ridership per route
monthly_ridership = (
    df_top.groupby(["month", "route_id"])["number_of_customers"]
    .sum()
    .reset_index()
)

monthly_ridership
# Save to CSV for Observable
#monthly_ridership.to_csv("monthly_ridership_top7.csv", index=False)


# Round down number_of_customers
monthly_ridership["number_of_customers"] = np.floor(monthly_ridership["number_of_customers"]).astype(int)

monthly_ridership.head()

df_pivot = monthly_ridership.pivot(index="month", columns="route_id", values="number_of_customers").fillna(0)
df_pivot.head()
'''
# Out:
# '\n# 1. Filter out Express buses\nimport pandas as pd\nimport numpy as np\n\ndf = df_bus_jrny\n\n# Aggregate total ridership per route\nroute_totals = df.groupby("route_id")["number_of_customers"].sum().sort_values(ascending=False)\ntop_routes = route_totals.head(7).index.tolist()\n\n# Filter only top 7 routes\ndf_top = df[df["route_id"].isin(top_routes)]\n\n# Aggregate monthly total ridership per route\nmonthly_ridership = (\n    df_top.groupby(["month", "route_id"])["number_of_customers"]\n    .sum()\n    .reset_index()\n)\n\nmonthly_ridership\n# Save to CSV for Observable\n#monthly_ridership.to_csv("monthly_ridership_top7.csv", index=False)\n\n\n# Round down number_of_customers\nmonthly_ridership["number_of_customers"] = np.floor(monthly_ridership["number_of_customers"]).astype(int)\n\nmonthly_ridership.head()\n\ndf_pivot = monthly_ridership.pivot(index="month", columns="route_id", values="number_of_customers").fillna(0)\ndf_pivot.head()\n'

# %%
import pandas as pd
import matplotlib.pyplot as plt

# make sure month is datetime
df_bus_jrny["month"] = pd.to_datetime(df_bus_jrny["month"])
df_bus_jrny["year"] = df_bus_jrny["month"].dt.year

# filter for 2024 and 2025
df_24_25 = df_bus_jrny[df_bus_jrny["year"].between(2017, 2025)]
print(df_24_25)

# Option 1: get summary statistics
distribution_summary = df_24_25[[
    "additional_bus_stop_time", 
    "additional_travel_time", 
    "customer_journey_time_performance"
]].describe()

print(distribution_summary)
# Out:
#            month        borough trip_type route_id    period  \
# 0     2017-08-01          Bronx   LCL/LTD      BX1  Off-Peak
# 1     2017-08-01          Bronx   LCL/LTD      BX1      Peak
# 2     2017-08-01          Bronx   LCL/LTD     BX10  Off-Peak
# 3     2017-08-01          Bronx   LCL/LTD     BX10      Peak
# 4     2017-08-01          Bronx   LCL/LTD     BX11  Off-Peak
# ...          ...            ...       ...      ...       ...
# 59734 2025-06-01  Staten Island   LCL/LTD      S94      Peak
# 59735 2025-06-01  Staten Island   LCL/LTD      S96  Off-Peak
# 59736 2025-06-01  Staten Island   LCL/LTD      S96      Peak
# 59737 2025-06-01  Staten Island   LCL/LTD      S98  Off-Peak
# 59738 2025-06-01  Staten Island   LCL/LTD      S98      Peak
#
#        number_of_customers  additional_bus_stop_time  additional_travel_time  \
# 0              219531.6357                  2.051653                0.696010
# 1              144822.4045                  1.963801                0.855400
# 2              142222.1974                  1.262757                0.150511
# 3               98257.1695                  0.869035               -0.195989
# 4              177312.8567                  1.555327                0.228310
# ...                    ...                       ...                     ...
# 59734           12983.8580                  3.175890                0.423085
# 59735            7887.4536                  5.706823                0.634270
# 59736           13606.5470                  6.850405                0.054585
# 59737            8488.3100                  5.961027                1.157760
# 59738           16078.5090                  9.796170                1.649481
#
#        customer_journey_time_performance  year
# 0                               0.702000  2017
# 1                               0.683975  2017
# 2                               0.782773  2017
# 3                               0.856885  2017
# 4                               0.772576  2017
# ...                                  ...   ...
# 59734                           0.667845  2025
# 59735                           0.617849  2025
# 59736                           0.555375  2025
# 59737                           0.553774  2025
# 59738                           0.431088  2025
#
# [45946 rows x 10 columns]
#        additional_bus_stop_time  additional_travel_time  \
# count              45946.000000            45946.000000
# mean                   2.590033                0.720137
# std                    1.661722                1.034936
# min                  -30.000000              -30.000000
# 25%                    1.686833                0.095813
# 50%                    2.276253                0.714731
# 75%                    3.063461                1.332055
# max                   48.621685                8.464616
#
#        customer_journey_time_performance
# count                       45945.000000
# mean                            0.702932
# std                             0.096417
# min                             0.000000
# 25%                             0.644661
# 50%                             0.706083
# 75%                             0.767322
# max                             1.000000

# %%
import pandas as pd

# assuming your DataFrame is named df_bus_jrny

# group by year and route_id, then take the mean of the relevant columns
df_grouped = (
    df_24_25
    .groupby(["year", "route_id"], as_index=False)
    .agg({
        "number_of_customers": "mean",
        "additional_bus_stop_time": "mean",
        "additional_travel_time": "mean",
        "customer_journey_time_performance": "mean"
    })
)

#df_grouped.head()
print(df_grouped)
# keep only rows where year is 2017 or 2025
df_filtered = df_grouped[df_grouped["year"].isin([2017, 2025])]

df_filtered.head()
print(df_filtered)
# Out:
#       year route_id  number_of_customers  additional_bus_stop_time  \
# 0     2017       B1        213420.622770                  1.806421
# 1     2017     B100         59305.585800                  1.172166
# 2     2017     B103        155342.720130                  1.990292
# 3     2017      B11        110253.874910                  1.799703
# 4     2017      B12        129514.137320                  2.410294
# ...    ...      ...                  ...                       ...
# 2305  2025      S92          6930.430075                  1.881703
# 2306  2025      S93         60118.753417                  3.196203
# 2307  2025      S94          8215.702375                  2.795077
# 2308  2025      S96         11883.709592                  5.575295
# 2309  2025      S98         13083.285250                  4.779545
#
#       additional_travel_time  customer_journey_time_performance
# 0                   1.681870                           0.692361
# 1                   1.595840                           0.731385
# 2                   2.662831                           0.602808
# 3                   1.018502                           0.694826
# 4                   1.061485                           0.661310
# ...                      ...                                ...
# 2305               -0.117817                           0.756832
# 2306               -0.752355                           0.707830
# 2307                0.355326                           0.732265
# 2308                0.310625                           0.626034
# 2309                1.128677                           0.598066
#
# [2310 rows x 6 columns]
#       year route_id  number_of_customers  additional_bus_stop_time  \
# 0     2017       B1        213420.622770                  1.806421
# 1     2017     B100         59305.585800                  1.172166
# 2     2017     B103        155342.720130                  1.990292
# 3     2017      B11        110253.874910                  1.799703
# 4     2017      B12        129514.137320                  2.410294
# ...    ...      ...                  ...                       ...
# 2305  2025      S92          6930.430075                  1.881703
# 2306  2025      S93         60118.753417                  3.196203
# 2307  2025      S94          8215.702375                  2.795077
# 2308  2025      S96         11883.709592                  5.575295
# 2309  2025      S98         13083.285250                  4.779545
#
#       additional_travel_time  customer_journey_time_performance
# 0                   1.681870                           0.692361
# 1                   1.595840                           0.731385
# 2                   2.662831                           0.602808
# 3                   1.018502                           0.694826
# 4                   1.061485                           0.661310
# ...                      ...                                ...
# 2305               -0.117817                           0.756832
# 2306               -0.752355                           0.707830
# 2307                0.355326                           0.732265
# 2308                0.310625                           0.626034
# 2309                1.128677                           0.598066
#
# [524 rows x 6 columns]

# %%
hist_journey_bus_stop_time = df_filtered[['year','additional_bus_stop_time']]
hist_journey_bus_add_time = df_filtered[['year','additional_travel_time']]
hist_journey_bus_total_time = df_filtered[['year','additional_travel_time']]
hist_journey_bus_journey_5 = df_filtered[['year','customer_journey_time_performance']]

# %%
#yearly_journey_bus_stop_time
# Get the absolute path to the project root
project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))

# Construct the full path to the output file
output_path = os.path.join(project_root, "data", "processed", "hist_journey_bus_stop_time.csv")

# Save the CSV
hist_journey_bus_stop_time.to_csv(output_path, index=False)


#yearly_journey_bus_add_time
# Get the absolute path to the project root
project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))

# Construct the full path to the output file
output_path = os.path.join(project_root, "data", "processed", "hist_journey_bus_add_time.csv")

# Save the CSV
hist_journey_bus_add_time.to_csv(output_path, index=False)


#yearly_journey_bus_total_time
# Get the absolute path to the project root
project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))

# Construct the full path to the output file
output_path = os.path.join(project_root, "data", "processed", "hist_journey_bus_total_time.csv")

# Save the CSV
hist_journey_bus_total_time.to_csv(output_path, index=False)


#yearly_journey_bus_journey_5
# Get the absolute path to the project root
project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))

# Construct the full path to the output file
output_path = os.path.join(project_root, "data", "processed", "hist_journey_bus_journey_5.csv")

# Save the CSV
hist_journey_bus_journey_5.to_csv(output_path, index=False)

# %%
import pandas as pd

# make sure month is datetime
df_bus_jrny["month"] = pd.to_datetime(df_bus_jrny["month"])

# extract year
df_bus_jrny["year"] = df_bus_jrny["month"].dt.year

# group by year and compute averages
yearly_journey_perf = (
    df_bus_jrny.groupby(["year","period"])
    .agg(
        additional_bus_stop_time_sum=("additional_bus_stop_time", "sum"),
        additional_travel_time_sum=("additional_travel_time", "sum"),
        customer_journey_time_performance_sum=("customer_journey_time_performance", "sum"),
        records=("month", "count")
    )
    .assign(
        avg_additional_bus_stop_time=lambda x: x["additional_bus_stop_time_sum"] / x["records"],
        avg_additional_travel_time=lambda x: x["additional_travel_time_sum"] / x["records"],
        avg_customer_journey_time_performance=lambda x: x["customer_journey_time_performance_sum"] / x["records"]
    )
    [["avg_additional_bus_stop_time", "avg_additional_travel_time", "avg_customer_journey_time_performance"]]
    .reset_index()
)

print(yearly_journey_perf)

# Get the absolute path to the project root
project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))

# Construct the full path to the output file
output_path = os.path.join(project_root, "data", "processed", "yearly_custperf.csv")

# Save the CSV
yearly_journey_perf.to_csv(output_path, index=False)
# Out:
#     year    period  avg_additional_bus_stop_time  avg_additional_travel_time  \
# 0   2017  Off-Peak                      2.137717                    1.379720
# 1   2017      Peak                      2.108817                    2.033415
# 2   2018  Off-Peak                      2.044230                    1.150474
# 3   2018      Peak                      2.006881                    1.762793
# 4   2019  Off-Peak                      2.675171                    1.116806
# 5   2019      Peak                      2.665712                    1.736412
# 6   2020  Off-Peak                      2.715947                   -0.469986
# 7   2020      Peak                      2.556263                   -0.438890
# 8   2021  Off-Peak                      3.337534                   -0.295028
# 9   2021      Peak                      3.194232                   -0.213170
# 10  2022  Off-Peak                      3.051107                    0.640814
# 11  2022      Peak                      3.054639                    0.920046
# 12  2023  Off-Peak                      2.892446                    0.859512
# 13  2023      Peak                      2.901743                    1.154400
# 14  2024  Off-Peak                      3.289606                    1.098747
# 15  2024      Peak                      3.291025                    1.272602
# 16  2025  Off-Peak                      2.912845                    0.674242
# 17  2025      Peak                      2.930621                    0.647964
#
#     avg_customer_journey_time_performance
# 0                                0.673031
# 1                                0.634755
# 2                                0.690950
# 3                                0.654336
# 4                                0.676072
# 5                                0.635853
# 6                                0.749683
# 7                                0.728985
# 8                                0.723356
# 9                                0.703498
# 10                               0.689537
# 11                               0.659503
# 12                               0.682113
# 13                               0.655137
# 14                               0.653777
# 15                               0.632092
# 16                               0.681301
# 17                               0.665507

# %%
#Bus Lane Infrastracture

# %%
# Path to data folder relative to the notebook
DATA_DIR = os.path.join("..", "data", "raw")
bus_lane_df = pd.read_csv(os.path.join(DATA_DIR, "bus_lanes_by_type.csv"))
bus_lane_df_type = pd.read_csv(os.path.join(DATA_DIR, "bus_lanes_built_upgraded.csv"))
#bus_jrny_df_2025 = pd.read_csv(os.path.join(DATA_DIR, "MTA_Bus_Customer_Journey-Focused_Metrics__Beginning_2025_20250819.csv"))

# %%
# Total miles of bus lanes by type
bus_lane_df
# Out:
#                Lane_Type  Mileage
# 0               Curbside    77.33
# 1                 Offset    66.60
# 2  Median/Center-Running     6.84
# 3                 Busway     5.72
# 4                  Other     4.71
# 5          Uncategorized     1.68

# %%
#Miles of bus lanes built and upgraded (2020-2024)
bus_lane_df_type
# Out:
#    Year  New_Lane_Miles  Miles_Upgraded
# 0  2024            5.48            13.5
# 1  2023           15.70             5.2
# 2  2022            7.80             4.4
# 3  2021           12.90             NaN
# 4  2020           16.30             NaN

# %%
#Employee Headcount
'''Bus service within New York City is operated by MTA agencies New York City Transit (NYCT) and MTA
Bus Company (MTABC). Some NYCT bus service is operated through the Manhattan and Bronx Surface
Transit Operating Authority (MaBSTOA), which is a subsidiary of NYCT.'''
# Out:
# 'Bus service within New York City is operated by MTA agencies New York City Transit (NYCT) and MTA\nBus Company (MTABC). Some NYCT bus service is operated through the Manhattan and Bronx Surface\nTransit Operating Authority (MaBSTOA), which is a subsidiary of NYCT.'

# %%
DATA_DIR = os.path.join("..", "data", "raw")
bus_emp_df = pd.read_csv(os.path.join(DATA_DIR, "MTA_Headcount__Beginning_2024_20250819.csv"))
bus_emp_df
# Out:
#        Fiscal Year       Month        Scenario  Financial Plan Year  \
# 0             2025  2025-05-01          Actual                 2025
# 1             2025  2025-05-01          Actual                 2025
# 2             2025  2025-05-01          Actual                 2025
# 3             2025  2025-05-01          Actual                 2025
# 4             2025  2025-05-01          Actual                 2025
# ...            ...         ...             ...                  ...
# 27091         2024  2024-01-01  Adopted Budget                 2024
# 27092         2024  2024-01-01  Adopted Budget                 2025
# 27093         2024  2024-01-01  Adopted Budget                 2024
# 27094         2024  2024-01-01  Adopted Budget                 2024
# 27095         2024  2024-01-01  Adopted Budget                 2025
#
#       Expense Type Agency        Function               Occupational Group  \
# 0           NREIMB  MTAHQ   Public Safety  Professional/Technical/Clerical
# 1            REIMB     CD     Engineering             Operational Hourlies
# 2           NREIMB   LIRR  Administration             Managers/Supervisors
# 3            REIMB    SIR     Engineering  Professional/Technical/Clerical
# 4           NREIMB   NYCT  Administration  Professional/Technical/Clerical
# ...            ...    ...             ...                              ...
# 27091        REIMB    SIR      Operations             Managers/Supervisors
# 27092       NREIMB  MTABC      Operations             Operational Hourlies
# 27093       NREIMB    MNR     Engineering  Professional/Technical/Clerical
# 27094        REIMB   LIRR      Operations             Managers/Supervisors
# 27095       NREIMB    SIR      Operations             Operational Hourlies
#
#        Positions
# 0          79.00
# 1          45.00
# 2         239.90
# 3           1.00
# 4         407.22
# ...          ...
# 27091       5.00
# 27092    2247.00
# 27093      -2.00
# 27094       8.00
# 27095     100.00
#
# [27096 rows x 9 columns]

# %%
#Bus Ridership

# %%
# Path to data folder relative to the notebook
DATA_DIR = os.path.join("..", "data", "raw")
bus_ridership_nyct_df_2014 = pd.read_csv(os.path.join(DATA_DIR, "nyc_transit_bus_ridership.csv"))
bus_ridership_mta_df_2014 = pd.read_csv(os.path.join(DATA_DIR, "mta_bus_company_ridership.csv"))
bus_ridership_df_2020 = pd.read_csv(os.path.join(DATA_DIR, "MTA_Daily_Ridership_Data__2020_-_2025_20250721.csv"))
bus_ridership_df_2025 = pd.read_csv(os.path.join(DATA_DIR, "MTA_Bus_Ridership_2025.csv"))
# Append (stack them vertically)
#df_bus_speed = pd.concat([bus_evasion_df_2015, bus_evasion_df_2020, bus_evasion_df_2025,], ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 8
#       6 bus_ridership_df_2025 = pd.read_csv(os.path.join(DATA_DIR, "MTA_Bus_Ridership_2025.csv"))
#       7 # Append (stack them vertically)
# ----> 8 df_bus_speed = pd.concat([bus_evasion_df_2015, bus_evasion_df_2020, bus_evasion_df_2025], ignore_index=True)
#
# NameError: name 'bus_evasion_df_2015' is not defined

# %%
bus_ridership_nyct_df_2014
bus_ridership_mta_df_2014
# Out:
#    Year  Average Weekday  Average Saturday  Average Sunday  Average Weekend  \
# 0  2014           407115            228304          175552           403826
# 1  2015           405978            228976          176503           405478
# 2  2016           407201            225844          174057           399902
# 3  2017           396229            222833          173565           396398
# 4  2018           392617            224751          170892           395643
# 5  2019           388075            228364          171762           400126
#
#    Annual Total
# 0     125581237
# 1     125399522
# 2     125617157
# 3     122214328
# 4     121448276
# 5     120551580

# %%
import pandas as pd

# Copy the Year column (assumes first column is Year)
years = bus_ridership_nyct_df_2014.iloc[:, 0]

# Add all other columns element-wise
bus_ridership_total_df_2014 = bus_ridership_nyct_df_2014.iloc[:, 1:].add(
    bus_ridership_mta_df_2014.iloc[:, 1:], fill_value=0
)

# Put Year back as first column
bus_ridership_total_df_2014.insert(0, "Year", years)

print(bus_ridership_total_df_2014)
# Create new dataframe with Year, Ridership, and Average Daily Ridership
summary_df = bus_ridership_total_df_2014[["Year", "Annual Total"]].rename(
    columns={"Annual Total": "Ridership"}
)

# Compute Average Daily Ridership
summary_df["Average Daily Ridership"] = summary_df["Ridership"] / 365

print(summary_df)
# Out:
#    Year  Average Weekday  Average Saturday  Average Sunday  Average Weekend  \
# 0  2014          2530207           1533741         1199831          2733542
# 1  2015          2476364           1507007         1172291          2679297
# 2  2016          2445320           1447143         1131484          2578627
# 3  2017          2320222           1391811         1097259          2489070
# 4  2018          2204222           1347377         1038949          2386326
# 5  2019          2158469           1337173         1019693          2356866
#
#    Annual Total
# 0     792632407
# 1     776081306
# 2     764030270
# 3     724834684
# 4     690809496
# 5     677588084
#    Year  Ridership  Average Daily Ridership
# 0  2014  792632407             2.171596e+06
# 1  2015  776081306             2.126250e+06
# 2  2016  764030270             2.093234e+06
# 3  2017  724834684             1.985848e+06
# 4  2018  690809496             1.892629e+06
# 5  2019  677588084             1.856406e+06

# %%
#Bus Ridership 2020-2025
bus_ridership_df_2020
import pandas as pd

# Ensure Date column is datetime
bus_ridership_df_2020["Date"] = pd.to_datetime(bus_ridership_df_2020["Date"])

# Extract year
bus_ridership_df_2020["Year"] = bus_ridership_df_2020["Date"].dt.year

# Group by year
summary_buses = (
    bus_ridership_df_2020
    .groupby("Year")
    .agg(
        Total_Ridership=("Buses: Total Estimated Ridership", "sum"),
        Days_Covered=("Date", "nunique")   # number of days with data
    )
    .reset_index()
)

# Compute average daily ridership
summary_buses["Avg_Daily_Ridership"] = (
    summary_buses["Total_Ridership"] / summary_buses["Days_Covered"]
)

#print(summary_buses)
# Drop 2025
summary_buses_clean = summary_buses[summary_buses["Year"] != 2025].copy()

# Keep only Year + Total_Ridership, rename
summary_buses_clean = summary_buses_clean[["Year", "Total_Ridership"]].rename(
    columns={"Total_Ridership": "Ridership"}
)

# Compute Average Daily Ridership (full year basis)
summary_buses_clean["Average Daily Ridership"] = summary_buses_clean["Ridership"] / 365

print(summary_buses_clean)
# Out:
#    Year  Ridership  Average Daily Ridership
# 0  2020  147387699             4.038019e+05
# 1  2021  381637866             1.045583e+06
# 2  2022  423946824             1.161498e+06
# 3  2023  425539799             1.165862e+06
# 4  2024  408872440             1.120198e+06

# %%
#Goes to 1/1/2025 - 8/5/2025
import pandas as pd

# Your dataframe is bus_ridership_df_2025
# Columns: ["bus_route", "ridership"]

# 1. Total ridership for given period
total_ridership = bus_ridership_df_2025["ridership"].sum()

# 2. Days covered (Jan 1 – Aug 5, 2025)
days_so_far = (pd.to_datetime("2025-08-05") - pd.to_datetime("2025-01-01")).days + 1

# 3. Daily average
daily_avg = total_ridership / days_so_far

# 4. Project full-year ridership
projected_ridership = daily_avg * 365

# 5. Create summary dataframe
summary_df_1 = pd.DataFrame({
    "Year": [2025, 2025],
    "Type": ["Actual (Jan 1–Aug 5)", "Projected (Full Year)"],
    "Ridership": [total_ridership, projected_ridership]
})

#print(summary_df)
import pandas as pd

# Days from Jan 1 – Aug 5, 2025
days_so_far = (pd.to_datetime("2025-08-05") - pd.to_datetime("2025-01-01")).days + 1

# Create a copy
summary_df_clean = summary_df_1.copy()

# Compute Average Daily Ridership
summary_df_clean["Average Daily Ridership"] = summary_df_clean.apply(
    lambda row: row["Ridership"] / days_so_far if "Actual" in row["Type"] else row["Ridership"] / 365,
    axis=1
)

# Transform to match other summary tables
summary_df_final = pd.DataFrame({
    "Year": summary_df_clean["Type"].apply(
        lambda x: "2025" if "Actual" in x else "2025*"
    ),
    "Ridership": summary_df_clean["Ridership"],
    "Average Daily Ridership": summary_df_clean["Average Daily Ridership"]
})

print(summary_df_final)
# Out:
#     Year     Ridership  Average Daily Ridership
# 0   2025  2.345365e+08             1.080813e+06
# 1  2025*  3.944969e+08             1.080813e+06

# %%
df_bus_ridership = pd.concat([summary_df, summary_buses_clean, summary_df_final], ignore_index=True)
df_bus_ridership
# Out:
#      Year     Ridership  Average Daily Ridership
# 0    2014  7.926324e+08             2.171596e+06
# 1    2015  7.760813e+08             2.126250e+06
# 2    2016  7.640303e+08             2.093234e+06
# 3    2017  7.248347e+08             1.985848e+06
# 4    2018  6.908095e+08             1.892629e+06
# 5    2019  6.775881e+08             1.856406e+06
# 6    2020  1.473877e+08             4.038019e+05
# 7    2021  3.816379e+08             1.045583e+06
# 8    2022  4.239468e+08             1.161498e+06
# 9    2023  4.255398e+08             1.165862e+06
# 10   2024  4.088724e+08             1.120198e+06
# 11   2025  2.345365e+08             1.080813e+06
# 12  2025*  3.944969e+08             1.080813e+06

# %%
# Get the absolute path to the project root
project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))

# Construct the full path to the output file
output_path = os.path.join(project_root, "data", "processed", "df_bus_ridership.csv")

# Save the CSV
df_bus_ridership.to_csv(output_path, index=False)

# %%
bus_ridership_df_2020 = pd.read_csv(os.path.join(DATA_DIR, "MTA_Daily_Ridership_Data__2020_-_2025_20250721.csv"))
bus_ridership_df_2020
import pandas as pd

# Ensure Date column is datetime
bus_ridership_df_2020["Date"] = pd.to_datetime(bus_ridership_df_2020["Date"])

# Filter for years 2022–2025
df_filtered = bus_ridership_df_2020[
    bus_ridership_df_2020["Date"].dt.year.isin([2022, 2023, 2024, 2025])
]

# Keep only weekdays (Monday=0, ..., Sunday=6)
df_weekdays = df_filtered[df_filtered["Date"].dt.weekday < 5]

# Compute average weekday ridership for buses
avg_weekday_ridership = df_weekdays["Buses: Total Estimated Ridership"].mean()

print(f"Average weekday bus ridership (2022–2025): {avg_weekday_ridership:,.0f}")
# Out:
# Average weekday bus ridership (2022–2025): 1,314,135

# %%
#Average Weekday Ridership Pre-Covid - 2,355,801
#Average Weekday Ridership Post-Covid - 1,314,135
