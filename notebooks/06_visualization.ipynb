# %%
#Hello

# %%
import requests
import random
import logging
from datetime import datetime, timedelta
import time

# 🔧 Config
API_KEY_ID = "5yx99dm30481n7svtve0c1e7t"
API_KEY_SECRET = "1t99at0isb9o5erxzsp1ngfn0fjv8zj46cpgo5q2pdbevzwy8q"
BASE_URL = "https://data.ny.gov/resource/vxuj-8kew.json"
NUM_SAMPLES = 5  # Number of random dates to fetch
START_DATE = datetime(2020, 3, 1)  # Dataset starts March 2020
END_DATE = datetime.today()

# 🪵 Logging setup
logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s - %(levelname)s - %(message)s"
)

def get_random_dates(n):
    """Randomly pick `n` full calendar dates between START_DATE and END_DATE."""
    total_days = (END_DATE - START_DATE).days
    sampled_days = random.sample(range(total_days), n)
    return [(START_DATE + timedelta(days=d)).strftime("%Y-%m-%d") for d in sampled_days]

def fetch_data_for_date(date_str):
    """Fetch ridership data for a specific date using basic auth."""
    url = f"{BASE_URL}?date={date_str}T00:00:00.000"

    try:
        response = requests.get(url, auth=(API_KEY_ID, API_KEY_SECRET))
        if response.status_code == 200:
            data = response.json()
            if data:
                logging.info(f"✅ Fetched {len(data)} records for {date_str}")
            else:
                logging.warning(f"⚠️ No data found for {date_str}")
            return data
        else:
            logging.error(f"❌ Failed to fetch {date_str}: {response.status_code} - {response.text}")
            return []
    except Exception as e:
        logging.error(f"❌ Error fetching data for {date_str}: {e}")
        return []

def sample_and_fetch_random_days(n):
    """Randomly sample `n` dates and fetch ridership data for each."""
    logging.info("🚀 Starting random full-day sampling from MTA ridership dataset...")
    sampled_dates = get_random_dates(n)
    logging.info(f"🎯 Randomly selected dates: {sampled_dates}")

    for date in sampled_dates:
        fetch_data_for_date(date)
        time.sleep(0.3)  # Pause to avoid hitting rate limits

if __name__ == "__main__":
    sample_and_fetch_random_days(NUM_SAMPLES)
# Out:
# 2025-08-02 20:31:07,133 - INFO - 🚀 Starting random full-day sampling from MTA ridership dataset...
# 2025-08-02 20:31:07,135 - INFO - 🎯 Randomly selected dates: ['2024-03-27', '2021-06-28', '2020-03-10', '2020-05-11', '2024-11-27']
# 2025-08-02 20:31:08,051 - INFO - ✅ Fetched 1 records for 2024-03-27
# 2025-08-02 20:31:08,946 - INFO - ✅ Fetched 1 records for 2021-06-28
# 2025-08-02 20:31:09,893 - INFO - ✅ Fetched 1 records for 2020-03-10
# 2025-08-02 20:31:10,610 - INFO - ✅ Fetched 1 records for 2020-05-11
# 2025-08-02 20:31:11,327 - INFO - ✅ Fetched 1 records for 2024-11-27

# %%
import requests
import random
import logging
from datetime import datetime, timedelta
import time
import csv

# 🔧 Config
API_KEY_ID = "5yx99dm30481n7svtve0c1e7t"
API_KEY_SECRET = "1t99at0isb9o5erxzsp1ngfn0fjv8zj46cpgo5q2pdbevzwy8q"
BASE_URL = "https://data.ny.gov/resource/wujg-7c2s.json"
NUM_SAMPLES = 5
START_DATE = datetime(2020, 3, 1)
END_DATE = datetime.today()
OUTPUT_FILE = "/Users/danielbrown/Desktop/mta_random_days.csv"

# 🪵 Logging setup
logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s - %(levelname)s - %(message)s"
)

def get_random_dates(n):
    total_days = (END_DATE - START_DATE).days
    sampled_days = random.sample(range(total_days), n)
    return [(START_DATE + timedelta(days=d)).strftime("%Y-%m-%d") for d in sampled_days]

def fetch_data_for_date(date_str, max_retries=3, retry_delay=2):
    logging.info(f"📅 Fetching all records for {date_str}...")
    all_records = []
    offset = 0
    limit = 1000
    done = False

    next_date = (datetime.strptime(date_str, "%Y-%m-%d") + timedelta(days=1)).strftime("%Y-%m-%d")
    where_clause = f"transit_timestamp >= '{date_str}T00:00:00' AND transit_timestamp < '{next_date}T00:00:00'"

    # Outer retry loop for the full fetch process
    for attempt in range(1, max_retries + 1):
        try:
            while not done:
                url = (
                    f"{BASE_URL}?$where={where_clause}"
                    f"&$limit={limit}&$offset={offset}"
                )
                response = requests.get(url, auth=(API_KEY_ID, API_KEY_SECRET))
                if response.status_code == 200:
                    batch = response.json()
                    logging.info(f"📦 Retrieved {len(batch)} records at offset {offset}")
                    all_records.extend(batch)

                    if len(batch) < limit:
                        done = True
                    else:
                        offset += limit
                else:
                    logging.warning(f"⚠️ API error {response.status_code}: {response.text}")
                    break

                time.sleep(0.25)  # politeness delay

            if len(all_records) == 0:
                logging.warning(f"🕒 Attempt {attempt}: Received 0 records for {date_str}. Retrying after {retry_delay} seconds...")
                time.sleep(retry_delay)
                offset = 0
                done = False
                retry_delay *= 2  # exponential backoff
            else:
                break  # success
        except Exception as e:
            logging.error(f"❌ Exception on attempt {attempt} for {date_str}: {e}")
            time.sleep(retry_delay)
            retry_delay *= 2

    if len(all_records) == 0:
        logging.error(f"🚫 No data retrieved for {date_str} after {max_retries} attempts.")

    logging.info(f"✅ Finished fetching {len(all_records)} records for {date_str}")
    return all_records



def write_to_csv(data_list, output_file):
    if not data_list:
        logging.warning("⚠️ No data to write.")
        return

    # Determine fieldnames from keys of the first record
    fieldnames = sorted(set().union(*(d.keys() for d in data_list)))

    try:
        with open(output_file, mode="w", newline="", encoding="utf-8") as f:
            writer = csv.DictWriter(f, fieldnames=fieldnames)
            writer.writeheader()
            writer.writerows(data_list)
        logging.info(f"📄 Successfully wrote {len(data_list)} rows to '{output_file}'")
    except Exception as e:
        logging.error(f"❌ Failed to write CSV: {e}")

def sample_and_fetch_random_days(n):
    logging.info("🚀 Starting random full-day sampling from MTA ridership dataset...")
    sampled_dates = get_random_dates(n)
    logging.info(f"🎯 Randomly selected dates: {sampled_dates}")

    all_data = []
    for date in sampled_dates:
        day_data = fetch_data_for_date(date)
        if day_data:
            all_data.extend(day_data)
        time.sleep(0.3)  # avoid hammering the API

    write_to_csv(all_data, OUTPUT_FILE)

if __name__ == "__main__":
    sample_and_fetch_random_days(NUM_SAMPLES)
# Out:
# 2025-08-03 10:37:31,869 - INFO - 🚀 Starting random full-day sampling from MTA ridership dataset...
# 2025-08-03 10:37:31,875 - INFO - 🎯 Randomly selected dates: ['2021-06-02', '2020-12-14', '2023-01-22', '2020-05-06', '2023-03-20']
# 2025-08-03 10:37:31,875 - INFO - 📅 Fetching all records for 2021-06-02...
# 2025-08-03 10:37:35,041 - INFO - 📦 Retrieved 1000 records at offset 0
# 2025-08-03 10:37:36,264 - INFO - 📦 Retrieved 1000 records at offset 1000
# 2025-08-03 10:37:37,033 - INFO - 📦 Retrieved 1000 records at offset 2000
# 2025-08-03 10:37:38,819 - INFO - 📦 Retrieved 1000 records at offset 3000
# 2025-08-03 10:37:39,741 - INFO - 📦 Retrieved 1000 records at offset 4000
# 2025-08-03 10:37:41,380 - INFO - 📦 Retrieved 1000 records at offset 5000
# 2025-08-03 10
- INFO - 📦 Retrieved 1000 records at offset 58000
# 2025-08-03 10:41:08,028 - INFO - 📦 Retrieved 1000 records at offset 59000
# 2025-08-03 10:41:08,705 - INFO - 📦 Retrieved 1000 records at offset 60000
# 2025-08-03 10:41:09,385 - INFO - 📦 Retrieved 1000 records at offset 61000
# 2025-08-03 10:41:10,071 - INFO - 📦 Retrieved 1000 records at offset 62000
# 2025-08-03 10:41:10,826 - INFO - 📦 Retrieved 1000 records at offset 63000
# 2025-08-03 10:41:11,596 - INFO - 📦 Retrieved 1000 records at offset 64000
# 2025-08-03 10:41:12,305 - INFO - 📦 Retrieved 1000 records at offset 65000
# 2025-08-03 10:41:13,027 - INFO - 📦 Retrieved 1000 records at offset 66000
# 2025-08-03 10:41:13,743 - INFO - 📦 Retrieved 1000 records at offset 67000
# 2025-08-03 10:41:14,455 - INFO - 📦 Retrieved 1000 records at offset 68000
# 2025-08-03 10:41:15,198 - INFO - 📦 Retrieved 1000 records at offset 69000
# 2025-08-03 10:41:16,002 - INFO - 📦 Retrieved 1000 records at offset 70000
# 2025-08-03 10:41:16,813 - INFO - 📦 Retrieved 1000 records at offset 71000
# 2025-08-03 10:41:17,663 - INFO - 📦 Retrieved 676 records at offset 72000
# 2025-08-03 10:41:17,919 - INFO - ✅ Finished fetching 72676 records for 2023-03-20
# 2025-08-03 10:41:20,240 - INFO - 📄 Successfully wrote 262425 rows to '/Users/danielbrown/Desktop/mta_random_days.csv'

# %%
import requests
import random
import logging
from datetime import datetime, timedelta
import time
import csv

# 🔧 Config
API_KEY_ID = "5yx99dm30481n7svtve0c1e7t"
API_KEY_SECRET = "1t99at0isb9o5erxzsp1ngfn0fjv8zj46cpgo5q2pdbevzwy8q"
BASE_URL = "https://data.ny.gov/resource/wujg-7c2s.json"
NUM_SAMPLES = 75
START_DATE = datetime(2021, 3, 1)
END_DATE = datetime.today()
OUTPUT_FILE = "/Users/danielbrown/Desktop/mta_random_days.csv"

# 🪵 Logging setup
logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s - %(levelname)s - %(message)s"
)

def get_random_date():
    total_days = (END_DATE - START_DATE).days
    random_day = random.randint(0, total_days)
    return (START_DATE + timedelta(days=random_day)).strftime("%Y-%m-%d")

def fetch_data_for_date(date_str, max_retries=3, retry_delay=2):
    logging.info(f"📅 Fetching all records for {date_str}...")
    all_records = []
    offset = 0
    limit = 1000
    done = False

    next_date = (datetime.strptime(date_str, "%Y-%m-%d") + timedelta(days=1)).strftime("%Y-%m-%d")
    where_clause = f"transit_timestamp >= '{date_str}T00:00:00' AND transit_timestamp < '{next_date}T00:00:00'"

    for attempt in range(1, max_retries + 1):
        try:
            while not done:
                url = (
                    f"{BASE_URL}?$where={where_clause}"
                    f"&$limit={limit}&$offset={offset}"
                )
                response = requests.get(url, auth=(API_KEY_ID, API_KEY_SECRET))
                if response.status_code == 200:
                    batch = response.json()
                    logging.info(f"📦 Retrieved {len(batch)} records at offset {offset}")
                    all_records.extend(batch)

                    if len(batch) < limit:
                        done = True
                    else:
                        offset += limit
                else:
                    logging.warning(f"⚠️ API error {response.status_code}: {response.text}")
                    break

                time.sleep(0.25)  # politeness delay

            if len(all_records) == 0:
                logging.warning(f"🕒 Attempt {attempt}: Received 0 records for {date_str}. Retrying after {retry_delay} seconds...")
                time.sleep(retry_delay)
                offset = 0
                done = False
                retry_delay *= 2
            else:
                break
        except Exception as e:
            logging.error(f"❌ Exception on attempt {attempt} for {date_str}: {e}")
            time.sleep(retry_delay)
            retry_delay *= 2

    if len(all_records) == 0:
        logging.error(f"🚫 No data retrieved for {date_str} after {max_retries} attempts.")

    logging.info(f"✅ Finished fetching {len(all_records)} records for {date_str}")
    return all_records

def write_to_csv(data_list, output_file):
    if not data_list:
        logging.warning("⚠️ No data to write.")
        return

    fieldnames = sorted(set().union(*(d.keys() for d in data_list)))

    try:
        with open(output_file, mode="w", newline="", encoding="utf-8") as f:
            writer = csv.DictWriter(f, fieldnames=fieldnames)
            writer.writeheader()
            writer.writerows(data_list)
        logging.info(f"📄 Successfully wrote {len(data_list)} rows to '{output_file}'")
    except Exception as e:
        logging.error(f"❌ Failed to write CSV: {e}")

def sample_and_fetch_random_days(n):
    logging.info("🚀 Starting random full-day sampling from MTA ridership dataset...")

    successful_dates = set()
    tried_dates = set()
    all_data = []

    while len(successful_dates) < n:
        date = get_random_date()
        if date in tried_dates:
            continue

        tried_dates.add(date)
        day_data = fetch_data_for_date(date)
        if day_data:
            all_data.extend(day_data)
            successful_dates.add(date)
        else:
            logging.info(f"🔁 Will sample another day to replace failed date: {date}")

        time.sleep(0.3)

    logging.info(f"🏁 Successfully retrieved data for {len(successful_dates)} unique days: {sorted(successful_dates)}")
    write_to_csv(all_data, OUTPUT_FILE)

if __name__ == "__main__":
    sample_and_fetch_random_days(NUM_SAMPLES)
# Out:
# 2025-08-03 10:48:05,441 - INFO - 🚀 Starting random full-day sampling from MTA ridership dataset...
# 2025-08-03 10:48:05,442 - INFO - 📅 Fetching all records for 2022-03-30...
# 2025-08-03 10:48:06,313 - INFO - 📦 Retrieved 1000 records at offset 0
# 2025-08-03 10:48:07,644 - INFO - 📦 Retrieved 1000 records at offset 1000
# 2025-08-03 10:48:08,556 - INFO - 📦 Retrieved 1000 records at offset 2000
# 2025-08-03 10:48:09,413 - INFO - 📦 Retrieved 1000 records at offset 3000
# 2025-08-03 10:48:10,205 - INFO - 📦 Retrieved 1000 records at offset 4000
# 2025-08-03 10:48:11,015 - INFO - 📦 Retrieved 1000 records at offset 5000
# 2025-08-03 10:48:12,042 - INFO - 📦 Retrieved 1000 records at offset 6000
# 2025-08-03 10:48:12,763 - INFO - 📦 Retrieved 1000 records at offset 7000
# 2025-08-03 10:48:13,475 - INFO - 📦 Retrieved 1000 records at offset 8000
# 2025-08-03 10:48:14,302 - INFO - 📦 Retrieved 1000 records at offset 9000
# 2025-08-03 10:48:15,054 - INFO - 📦 Retrieved 1000 records at offset 10000
# 2025-08-03 10:48:15,801 - INFO - 📦 Retrieved 1000 records at offset 11000
# 2025-08-03 10:48:16,652 - INFO - 📦 Retrieved 1000 records at offset 12000
# 2025-08-03 10:48:17,454 - INFO - 📦 Retrieved 1000 records at offset 13000
# 2025-08-03 10:48:18,184 - INFO - 📦 Retrieved 1000 records at offset 14000
# 2025-08-03 10:48:18,905 - INFO - 📦 Retrieved 1000 records at offset 15000
# 2025-08-03 10:48:19,834 - INFO - 📦 Retrieved 1000 records at offset 16000
# 2025-08-03 10:48:20,539 - INFO - 📦 Retrieved 1000 records at offset 17000
# 2025-08-03 10:48:21,267 - INFO - 📦 Retrieved 1000 records at offset 18000
# 2025-08-03 10:48:21,895 - INFO - 📦 Retrieved 1000 records at offset 19000
# 2025-08-03 10:48:22,587 - INFO - 📦 Retrieved 1000 records at offset 20000
# 2025-08-03 10:48:23,362 - INFO - 📦 Retrieved 1000 records at offset 21000
# 2025-08-03 10:48:24,118 - INFO - 📦 Retrieved 1000 records at offset 22000
# 2025-08-03 10:48:24,850 - INFO - 📦 Retrieved 1000 records at offset 23000
# 2025-08-03 10:48:25,596 - INFO - 📦 Retrieved 1000 records at offset 24000
# 2025-08-03 10:48:26,377 - INFO - 📦 Retrieved 1000 records at offset 25000
# 2025-08-03 10:48:27,092 - INFO - 📦 Retrieved 1000 records at offset 26000
# 2025-08-03 10:48:27,912 - INFO - 📦 Retrieved 1000 records at offset 27000
# 2025-08-03 10:48:28,624 - INFO - 📦 Retrieved 1000 records at offset 28000
# 2025-08-03 10:48:29,473 - INFO - 📦 Retrieved 1000 records at offset 29000
# 2025-08-03 10:48:30,267 - INFO - 📦 Retrieved 1000 records at offset 30000
# 2025-08-03 10:48:31,089 - INFO - 📦 Retrieved 1000 records at offset 31000
# 2025-08-03 10:48:31,829 - INFO - 📦 Retrieved 1000 records at offset 32000
# 2025-08-03 10:48:32,622 - INFO - 📦 Retrieved 1000 records at offset 33000
# 2025-08-03 10:48:33,444 - INFO - 📦 Retrieved 1000 records at offset 34000
# 2025-08-03 10:48:34,264 - INFO - 📦 Retrieved 1000 records at offset 35000
# 2025-08-03 10:48:34,974 - INFO - 📦 Retrieved 1000 records at offset 36000
# 2025-08-03 10:48:35,697 - INFO - 📦 Retrieved 1000 records at offset 37000
# 2025-08-03 10:48:36,493 - INFO - 📦 Retrieved 1000 records at offset 38000
# 2025-08-03 10:48:37,432 - INFO - 📦 Retrieved 1000 records at offset 39000
# 2025-08-03 10:48:38,149 - INFO - 📦 Retrieved 1000 records at offset 40000
# 2025-08-03 10:48:38,973 - INFO - 📦 Retrieved 1000 records at offset 41000
# 2025-08-03 10:48:39,661 - INFO - 📦 Retrieved 1000 records at offset 42000
# 2025-08-03 10:48:40,410 - INFO - 📦 Retrieved 1000 records at offset 43000
# 2025-08-03 10:48:41,123 - INFO - 📦 Retrieved 1000 records at offset 44000
# 2025-08-03 10:48:41,835 - INFO - 📦 Retrieved 1000 records at offset 45000
# 2025-08-03 10:48:42,659 - INFO - 📦 Retrieved 1000 records at offset 46000
# 2025-08-03 10:48:43,423 - INFO - 📦 Retrieved 1000 records at offset 47000
# 2025-08-03 10:48:44,300 - INFO - 📦 Retrieved 1000 records at offset 48000
# 2025-08-03 10:48:45,000 - INFO - 📦 Retrieved 1000 records at offset 49000
# 2025-08-03 10:48:45,729 - INFO - 📦 Retrieved 1000 records at offset 50000
# 2025-08-03 10:48:46,444 - INFO - 📦 Retrieved 1000 records at offset 51000
# 2025-08-03 10:48:47,264 - INFO - 📦 Retrieved 1000 records at offset 52000
# 2025-08-03 10:48:47,969 - INFO - 📦 Retrieved 1000 records at offset 53000
# 2025-08-03 10:48:48,706 - INFO - 📦 Retrieved 1000 records at offset 54000
# 2025-08-03 10:48:49,399 - INFO - 📦 Retrieved 1000 records at offset 55000
# 2025-08-03 10:48:50,092 - INFO - 📦 Retrieved 1000 records at offset 56000
# 2025-08-03 10:48:51,058 - INFO - 📦 Retrieved 1000 records at offset 57000
# 2025-08-03 10:48:51,766 - INFO - 📦 Retrieved 1000 records at offset 58000
# 2025-08-03 10:48:52,490 - INFO - 📦 Retrieved 1000 records at offset 59000
# 2025-08-03 10:48:53,203 - INFO - 📦 Retrieved 1000 records at offset 60000
# 2025-08-03 10:48:53,925 - INFO - 📦 Retrieved 1000 records at offset 61000
# 2025-08-03 10:48:54,740 - INFO - 📦 Retrieved 1000 records at offset 62000
# 2025-08-03 10:48:55,562 - INFO - 📦 Retrieved 1000 records at offset 63000
# 2025-08-03 10:48:56,381 - INFO - 📦 Retrieved 1000 records at offset 64000
# 2025-08-03 10:48:57,071 - INFO - 📦 Retrieved 1000 records at offset 65000
- INFO - 📦 Retrieved 1000 records at offset 6000
# 2025-08-03 10:50:34,287 - INFO - 📦 Retrieved 1000 records at offset 7000
# 2025-08-03 10:50:35,147 - INFO - 📦 Retrieved 1000 records at offset 8000
# 2025-08-03 10:50:36,078 - INFO - 📦 Retrieved 1000 records at offset 9000
# 2025-08-03 10:50:36,964 - INFO - 📦 Retrieved 1000 records at offset 10000
# 2025-08-03 10:50:37,694 - INFO - 📦 Retrieved 1000 records at offset 11000
# 2025-08-03 10:50:38,481 - INFO - 📦 Retrieved 1000 records at offset 12000
# 2025-08-03 10:50:39,296 - INFO - 📦 Retrieved 1000 records at offset 13000
# 2025-08-03 10:50:40,029 - INFO - 📦 Retrieved 1000 records at offset 14000
# 2025-08-03 10:50:40,837 - INFO - 📦 Retrieved 1000 records at offset 15000
# 2025-08-03 10:50:41,703 - INFO - 📦 Retrieved 1000 records at offset 16000
# 2025-08-03 10:50:42,464 - INFO - 📦 Retrieved 1000 records at offset 17000
# 2025-08-03 10:50:43,176 - INFO - 📦 Retrieved 1000 records at offset 18000
# 2025-08-03 10:50:43,950 - INFO - 📦 Retrieved 1000 records at offset 19000
# 2025-08-03 10:50:44,734 - INFO - 📦 Retrieved 1000 records at offset 20000
# 2025-08-03 10:50:45,548 - INFO - 📦 Retrieved 1000 records at offset 21000
# 2025-08-03 10:50:46,279 - INFO - 📦 Retrieved 1000 records at offset 22000
# 2025-08-03 10:50:47,087 - INFO - 📦 Retrieved 1000 records at offset 23000
# 2025-08-03 10:50:48,003 - INFO - 📦 Retrieved 1000 records at offset 24000
# 2025-08-03 10:50:48,742 - INFO - 📦 Retrieved 1000 records at offset 25000
# 2025-08-03 10:50:49,455 - INFO - 📦 Retrieved 1000 records at offset 26000
# 2025-08-03 10:50:50,206 - INFO - 📦 Retrieved 1000 records at offset 27000
# 2025-08-03 10:50:51,127 - INFO - 📦 Retrieved 1000 records at offset 28000
# 2025-08-03 10:50:51,967 - INFO - 📦 Retrieved 1000 records at offset 29000
# 2025-08-03 10:50:52,714 - INFO - 📦 Retrieved 1000 records at offset 30000
# 2025-08-03 10:50:53,423 - INFO - 📦 Retrieved 1000 records at offset 31000
# 2025-08-03 10:50:54,252 - INFO - 📦 Retrieved 1000 records at offset 32000
# 2025-08-03 10:50:54,976 - INFO - 📦 Retrieved 1000 records at offset 33000
# 2025-08-03 10:50:55,684 - INFO - 📦 Retrieved 1000 records at offset 34000
# 2025-08-03 10:50:56,375 - INFO - 📦 Retrieved 1000 records at offset 35000
# 2025-08-03 10:50:57,065 - INFO - 📦 Retrieved 1000 records at offset 36000
# 2025-08-03 10:50:57,829 - INFO - 📦 Retrieved 1000 records at offset 37000
# 2025-08-03 10:50:58,594 - INFO - 📦 Retrieved 1000 records at offset 38000
# 2025-08-03 10:50:59,382 - INFO - 📦 Retrieved 1000 records at offset 39000
# 2025-08-03 10:51:00,169 - INFO - 📦 Retrieved 1000 records at offset 40000
# 2025-08-03 10:51:00,988 - INFO - 📦 Retrieved 1000 records at offset 41000
# 2025-08-03 10:51:01,838 - INFO - 📦 Retrieved 1000 records at offset 42000
# 2025-08-03 10:51:02,715 - INFO - 📦 Retrieved 1000 records at offset 43000
# 2025-08-03 10:51:03,559 - INFO - 📦 Retrieved 1000 records at offset 44000
# 2025-08-03 10:51:04,407 - INFO - 📦 Retrieved 1000 records at offset 45000
# 2025-08-03 10:51:05,715 - INFO - 📦 Retrieved 1000 records at offset 46000
# 2025-08-03 10:51:06,474 - INFO - 📦 Retrieved 1000 records at offset 47000
# 2025-08-03 10:51:07,226 - INFO - 📦 Retrieved 1000 records at offset 48000
# 2025-08-03 10:51:07,907 - INFO - 📦 Retrieved 1000 records at offset 49000
# 2025-08-03 10:51:08,599 - INFO - 📦 Retrieved 1000 records at offset 50000
# 2025-08-03 10:51:09,311 - INFO - 📦 Retrieved 1000 records at offset 51000
# 2025-08-03 10:51:10,112 - INFO - 📦 Retrieved 1000 records at offset 52000
# 2025-08-03 10:51:10,938 - INFO - 📦 Retrieved 1000 records at offset 53000
# 2025-08-03 10:51:11,596 - INFO - 📦 Retrieved 1000 records at offset 54000
# 2025-08-03 10:51:12,263 - INFO - 📦 Retrieved 1000 records at offset 55000
# 2025-08-03 10:51:12,957 - INFO - 📦 Retrieved 1000 records at offset 56000
# 2025-08-03 10:51:13,635 - INFO - 📦 Retrieved 1000 records at offset 57000
# 2025-08-03 10:51:14,510 - INFO - 📦 Retrieved 1000 records at offset 58000
# 2025-08-03 10:51:15,210 - INFO - 📦 Retrieved 1000 records at offset 59000
# 2025-08-03 10:51:16,064 - INFO - 📦 Retrieved 1000 records at offset 60000
# 2025-08-03 10:51:16,994 - INFO - 📦 Retrieved 1000 records at offset 61000
# 2025-08-03 10:51:17,756 - INFO - 📦 Retrieved 1000 records at offset 62000
# 2025-08-03 10:51:18,454 - INFO - 📦 Retrieved 1000 records at offset 63000
# 2025-08-03 10:51:19,150 - INFO - 📦 Retrieved 1000 records at offset 64000
# 2025-08-03 10:51:19,844 - INFO - 📦 Retrieved 1000 records at offset 65000
# 2025-08-03 10:51:20,585 - INFO - 📦 Retrieved 1000 records at offset 66000
# 2025-08-03 10:51:21,390 - INFO - 📦 Retrieved 1000 records at offset 67000
# 2025-08-03 10:51:22,176 - INFO - 📦 Retrieved 1000 records at offset 68000
# 2025-08-03 10:51:22,975 - INFO - 📦 Retrieved 1000 records at offset 69000
# 2025-08-03 10:51:23,751 - INFO - 📦 Retrieved 1000 records at offset 70000
# 2025-08-03 10:51:24,478 - INFO - 📦 Retrieved 1000 records at offset 71000
# 2025-08-03 10:51:25,169 - INFO - 📦 Retrieved 1000 records at offset 72000
# 2025-08-03 10:51:26,001 - INFO - 📦 Retrieved 1000 records at offset 73000
# 2025-08-03 10:51:26,676 - INFO - 📦 Retrieved 863 records at offset 74000
# 2025-08-03 10:51:26,933 - INFO - ✅ Finished fetching 74863 records for 2023-12-13
# 2025-08-03 10:51:27,346 - INFO - 📅 Fetching all records for 2023-11-01...
# 2025-08-03 10:51:27,901 - INFO - 📦 Retrieved 1000 records at offset 0
# 2025-08-03 10:51:28,657 - INFO - 📦 Retrieved 1000 records at offset 1000
# 2025-08-03 10:51:29,573 - INFO - 📦 Retrieved 1000 records at offset 2000
# 2025-08-03 10:51:30,295 - INFO - 📦 Retrieved 1000 records at offset 3000
# 2025-08-03 10:51:30,930 - INFO - 📦 Retrieved 1000 records at offset 4000
# 2025-08-03 10:51:31,611 - INFO - 📦 Retrieved 1000 records at offset 5000
# 2025-08-03 10:51:32,234 - INFO - 📦 Retrieved 1000 records at offset 6000
# 2025-08-03 10:51:32,963 - INFO - 📦 Retrieved 1000 records at offset 7000
# 2025-08-03 10:51:33,708 - INFO - 📦 Retrieved 1000 records at offset 8000
# 2025-08-03 10:51:34,407 - INFO - 📦 Retrieved 1000 records at offset 9000
# 2025-08-03 10:51:35,188 - INFO - 📦 Retrieved 1000 records at offset 10000
# 2025-08-03 10:51:35,906 - INFO - 📦 Retrieved 1000 records at offset 11000
# 2025-08-03 10:51:36,611 - INFO - 📦 Retrieved 1000 records at offset 12000
# 2025-08-03 10:51:37,444 - INFO - 📦 Retrieved 1000 records at offset 13000
# 2025-08-03 10:51:38,180 - INFO - 📦 Retrieved 1000 records at offset 14000
# 2025-08-03 10:51:38,843 - INFO - 📦 Retrieved 1000 records at offset 15000
# 2025-08-03 10:51:39,489 - INFO - 📦 Retrieved 1000 records at offset 16000
# 2025-08-03 10:51:40,133 - INFO - 📦 Retrieved 1000 records at offset 17000
# 2025-08-03 10:51:40,939 - INFO - 📦 Retrieved 1000 records at offset 18000
# 2025-08-03 10:51:41,664 - INFO - 📦 Retrieved 1000 records at offset 19000
# 2025-08-03 10:51:42,494 - INFO - 📦 Retrieved 1000 records at offset 20000
# 2025-08-03 10:51:43,274 - INFO - 📦 Retrieved 1000 records at offset 21000
# 2025-08-03 10:51:44,056 - INFO - 📦 Retrieved 1000 records at offset 22000
# 2025-08-03 10:51:44,800 - INFO - 📦 Retrieved 1000 records at offset 23000
# 2025-08-03 10:51:45,455 - INFO - 📦 Retrieved 1000 records at offset 24000
# 2025-08-03 10:51:46,291 - INFO - 📦 Retrieved 1000 records at offset 25000
# 2025-08-03 10:51:47,104 - INFO - 📦 Retrieved 1000 records at offset 26000
# 2025-08-03 10:51:47,911 - INFO - 📦 Retrieved 1000 records at offset 27000
# 2025-08-03 10:51:48,624 - INFO - 📦 Retrieved 1000 records at offset 28000
# 2025-08-03 10:51:49,432 - INFO - 📦 Retrieved 1000 records at offset 29000
# 2025-08-03 10:51:50,091 - INFO - 📦 Retrieved 1000 records at offset 30000
# 2025-08-03 10:51:50,878 - INFO - 📦 Retrieved 1000 records at offset 31000
# 2025-08-03 10:51:51,531 - INFO - 📦 Retrieved 1000 records at offset 32000
# 2025-08-03 10:51:52,276 - INFO - 📦 Retrieved 1000 records at offset 33000
# 2025-08-03 10:51:52,967 - INFO - 📦 Retrieved 1000 records at offset 34000
# 2025-08-03 10:51:53,628 - INFO - 📦 Retrieved 1000 records at offset 35000
# 2025-08-03 10:51:54,360 - INFO - 📦 Retrieved 1000 records at offset 36000
# 2025-08-03 10:51:55,571 - INFO - 📦 Retrieved 1000 records at offset 37000
# 2025-08-03 10:51:56,369 - INFO - 📦 Retrieved 1000 records at offset 38000
# 2025-08-03 10:51:57,124 - INFO - 📦 Retrieved 1000 records at offset 39000
# 2025-08-03 10:51:57,836 - INFO - 📦 Retrieved 1000 records at offset 40000
# 2025-08-03 10:51:58,660 - INFO - 📦 Retrieved 1000 records at offset 41000
# 2025-08-03 10:51:59,479 - INFO - 📦 Retrieved 1000 records at offset 42000
# 2025-08-03 10:52:00,153 - INFO - 📦 Retrieved 1000 records at offset 43000
# 2025-08-03 10:52:00,814 - INFO - 📦 Retrieved 1000 records at offset 44000
# 2025-08-03 10:52:01,529 - INFO - 📦 Retrieved 1000 records at offset 45000
# 2025-08-03 10:52:02,253 - INFO - 📦 Retrieved 1000 records at offset 46000
# 2025-08-03 10:52:02,907 - INFO - 📦 Retrieved 1000 records at offset 47000
# 2025-08-03 10:52:03,889 - INFO - 📦 Retrieved 1000 records at offset 48000
# 2025-08-03 10:52:04,569 - INFO - 📦 Retrieved 1000 records at offset 49000
# 2025-08-03 10:52:05,413 - INFO - 📦 Retrieved 1000 records at offset 50000
# 2025-08-03 10:52:06,238 - INFO - 📦 Retrieved 1000 records at offset 51000
# 2025-08-03 10:52:07,054 - INFO - 📦 Retrieved 1000 records at offset 52000
# 2025-08-03 10:52:07,738 - INFO - 📦 Retrieved 1000 records at offset 53000
# 2025-08-03 10:52:08,493 - INFO - 📦 Retrieved 1000 records at offset 54000
# 2025-08-03 10:52:09,267 - INFO - 📦 Retrieved 1000 records at offset 55000
# 2025-08-03 10:52:10,025 - INFO - 📦 Retrieved 1000 records at offset 56000
# 2025-08-03 10:52:10,736 - INFO - 📦 Retrieved 1000 records at offset 57000
# 2025-08-03 10:52:11,447 - INFO - 📦 Retrieved 1000 records at offset 58000
# 2025-08-03 10:52:12,139 - INFO - 📦 Retrieved 1000 records at offset 59000
# 2025-08-03 10:52:12,930 - INFO - 📦 Retrieved 1000 records at offset 60000
# 2025-08-03 10:52:13,617 - INFO - 📦 Retrieved 1000 records at offset 61000
# 2025-08-03 10:52:14,292 - INFO - 📦 Retrieved 1000 records at offset 62000
# 2025-08-03 10:52:15,039 - INFO - 📦 Retrieved 1000 records at offset 63000
# 2025-08-03 10:52:15,782 - INFO - 📦 Retrieved 1000 records at offset 64000
# 2025-08-03 10:52:16,589 - INFO - 📦 Retrieved 1000 records at offset 65000
# 2025-08-03 10:52:17,375 - INFO - 📦 Retrieved 1000 records at offset 66000
# 2025-08-03 10:52:18,130 - INFO - 📦 Retrieved 1000 records at offset 67000
# 2025-08-03 10:52:18,941 - INFO - 📦 Retrieved 1000 records at offset 68000
# 2025-08-03 10:52:19,651 - INFO - 📦 Retrieved 1000 records at offset 69000
# 2025-08-03 10:52:20,471 - INFO - 📦 Retrieved 1000 records at offset 70000
# 2025-08-03 10:52:21,269 - INFO - 📦 Retrieved 1000 records at offset 71000
# 2025-08-03 10:52:22,110 - INFO - 📦 Retrieved 1000 records at offset 72000
# 2025-08-03 10:52:22,981 - INFO - 📦 Retrieved 1000 records at offset 73000
# 2025-08-03 10:52:23,742 - INFO - 📦 Retrieved 872 records at offset 74000
# 2025-08-03 10:52:23,999 - INFO - ✅ Finished fetching 74872 records for 2023-11-01
# 2025-08-03 10:52:24,436 - INFO - 🏁 Successfully retrieved data for 5 unique days: ['2020-11-01', '2020-11-24', '2022-03-30', '2023-11-01', '2023-12-13']
# 2025-08-03 10:52:27,040 - INFO - 📄 Successfully wrote 331569 rows to '/Users/danielbrown/Desktop/mta_random_days.csv'
